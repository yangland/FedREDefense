# %%
from codes.npz_reader import *

# %%
file_path = 'results/Mar.29_16.32.25/2731612_fmnist_NO_fltrust_0.05.npz'

plot_validation_accuracies(file_path)
plot_gradient_norms(file_path)
plot_cosine_similarities(file_path)
# plot_vali_acc(file_path)
# plot_mali_selection(file_path)
plot_vali_acc_and_mali_selection(file_path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 file_path = 'results/Mar.29_16.32.25/2731612_fmnist_NO_fltrust_0.05.npz'
# ----> 3 plot_validation_accuracies(file_path)
#       4 plot_gradient_norms(file_path)
#       5 plot_cosine_similarities(file_path)
#
# File ~/GitHub/FedREDefense/codes/npz_reader.py:119, in plot_validation_accuracies(file_path)
#     116 """Plots validation accuracies from an .npz file."""
#     117 keys = ['server_vali_acc', 'benign_mean_vali_acc',
#     118         'mali_trained_vali_acc', 'mali_normalized_vali_acc', 'mali_scaled_vali_acc']
# --> 119 plot_metrics_from_npz(file_path, keys, "Validation Accuracies Over Epochs", "Accuracy")
#
# File ~/GitHub/FedREDefense/codes/npz_reader.py:77, in plot_metrics_from_npz(file_path, keys, title, ylabel, markersize)
#      74 one = np.load(file_path)
#      76 # Extract data for specified keys
# ---> 77 data = {key: one[key] for key in keys}
#      79 # Find the minimum length among the data arrays
#      80 min_length = min(len(arr) for arr in data.values())
#
# File ~/GitHub/FedREDefense/codes/npz_reader.py:77, in <dictcomp>(.0)
#      74 one = np.load(file_path)
#      76 # Extract data for specified keys
# ---> 77 data = {key: one[key] for key in keys}
#      79 # Find the minimum length among the data arrays
#      80 min_length = min(len(arr) for arr in data.values())
#
# File ~/micromamba/envs/fl39/lib/python3.9/site-packages/numpy/lib/_npyio_impl.py:263, in NpzFile.__getitem__(self, key)
#     261         return self.zip.read(key)
#     262 else:
# --> 263     raise KeyError(f"{key} is not a file in the archive")
#
# KeyError: 'server_vali_acc is not a file in the archive'

# %%
a = dict(a=1, b=2)

# %%
[3]*4
# Out:
# [3, 3, 3, 3]
