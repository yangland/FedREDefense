# %% [markdown]
# ## Org MADS

# %%
import numpy as np

def objective(x):
    a, b, c = x
    return (a - 0.5)**2 + (b - 15)**2 + (c - 1.5)**2  # Example function

# Bounds for each variable
bounds = np.array([[0, 1], [10, 20], [0, 3]])

# Initial guess
x0 = np.array([0.9, 19, 0.1])

def mads(func, x0, bounds, delta=1.0, tol=1e-6, max_iter=100):
    """ Mesh Adaptive Direct Search (MADS) implementation. """
    n = len(x0)
    x = x0.copy()
    delta_min = tol
    iteration = 0
    
    while delta > delta_min and iteration < max_iter:
        improved = False
        
        # Generate trial points
        for i in range(n):
            for direction in [-1, 1]:
                x_new = x.copy()
                x_new[i] += direction * delta
                x_new = np.clip(x_new, bounds[:, 0], bounds[:, 1])  # Enforce bounds
                
                if func(x_new) < func(x):
                    x = x_new
                    improved = True
        
        # Reduce mesh size if no improvement
        if not improved:
            delta /= 2.0
        
        iteration += 1
        yield x, func(x), iteration

# Run MADS optimization
mads_iter = mads(objective, x0, bounds)
for x, fval, step in mads_iter:
    print(f"Step {step}: x = {x}, f(x) = {fval}")

# %% [markdown]
# ### Stepwise MADS, on iterations

# %%
import numpy as np

class StepwiseMADS:
    def __init__(self, x0, bounds, delta0=1.0, delta_min=1e-3, alpha=2.0, gamma=0.5):
        self.x = np.array(x0)
        self.bounds = np.array(bounds)
        self.delta = delta0
        self.delta_min = delta_min
        self.alpha = alpha
        self.gamma = gamma
        self.mesh_size = delta0
        self.iteration = 0
        self.pending_eval = None
        self.best_value = None  # Store the best evaluation value
    
    def get_next_candidate(self):
        if self.pending_eval is not None:
            raise RuntimeError("Previous evaluation result is still pending.")
        
        directions = np.eye(len(self.x))
        candidates = [self.x + self.mesh_size * d for d in directions] + [self.x - self.mesh_size * d for d in directions]
        
        candidates = [np.clip(c, self.bounds[:, 0], self.bounds[:, 1]) for c in candidates]
        self.pending_eval = candidates.copy()
        return candidates
    
    def update_with_result(self, evaluations):
        if self.pending_eval is None:
            raise RuntimeError("No pending evaluations to update with.")
        
        best_idx = np.argmin(evaluations)
        best_candidate = self.pending_eval[best_idx]
        best_value = evaluations[best_idx]
        
        if self.best_value is None or best_value < self.best_value:
            self.x = best_candidate
            self.best_value = best_value
            self.mesh_size *= self.alpha
        else:
            self.mesh_size *= self.gamma
        
        self.mesh_size = max(self.mesh_size, self.delta_min)
        self.pending_eval = None
        self.iteration += 1
    
    def get_current_solution(self):
        return self.x

# %%
# Example Usage
def obj_func(x):
    a, b, c = x
    return (a - 0.5)**2 + (b - 15)**2 + (c - 1.5)**2  # Example function

bounds = np.array([[0, 1], [10, 20], [0, 3]])
mads = StepwiseMADS(x0=[0.9, 19, 0.1], bounds=bounds)
mads.best_value = obj_func(mads.x)  # Initialize best value with initial point evaluation

for _ in range(20):  # Run for a few iterations
    candidates = mads.get_next_candidate()
    evaluations = [obj_func(c) for c in candidates]  # Simulated evaluation
    mads.update_with_result(evaluations)
    print(f"Iteration {_}: Best solution {mads.get_current_solution()} with value {mads.best_value}")
# Out:
# Iteration 0: Best solution [ 0.9 18.   0.1] with value 11.12
# Iteration 1: Best solution [ 0.9 16.   0.1] with value 3.12
# Iteration 2: Best solution [ 0.9 16.   0.1] with value 3.12
# Iteration 3: Best solution [ 0.9 16.   2.1] with value 1.5200000000000002
# Iteration 4: Best solution [ 0.9 16.   2.1] with value 1.5200000000000002
# Iteration 5: Best solution [ 0.9 16.   2.1] with value 1.5200000000000002
# Iteration 6: Best solution [ 0.9 15.   2.1] with value 0.5200000000000001
# Iteration 7: Best solution [ 0.9 15.   2.1] with value 0.5200000000000001
# Iteration 8: Best solution [ 0.9 15.   1.1] with value 0.31999999999999995
# Iteration 9: Best solution [ 0.9 15.   1.1] with value 0.31999999999999995
# Iteration 10: Best solution [ 0.9 15.   1.1] with value 0.31999999999999995
# Iteration 11: Best solution [ 0.4 15.   1.1] with value 0.16999999999999993
# Iteration 12: Best solution [ 0.4 15.   1.1] with value 0.16999999999999993
# Iteration 13: Best solution [ 0.4 15.   1.6] with value 0.02000000000000001
# Iteration 14: Best solution [ 0.4 15.   1.6] with value 0.02000000000000001
# Iteration 15: Best solution [ 0.4 15.   1.6] with value 0.02000000000000001
# Iteration 16: Best solution [ 0.4 15.   1.6] with value 0.02000000000000001
# Iteration 17: Best solution [ 0.4   15.     1.475] with value 0.01062499999999999
# Iteration 18: Best solution [ 0.4   15.     1.475] with value 0.01062499999999999
# Iteration 19: Best solution [ 0.525 15.     1.475] with value 0.0012499999999999968

# %% [markdown]
# ## Stp on every call

# %%
import math

# %%
class MADS:
    def __init__(self, x0, bounds, delta0=1.0, delta_min=1e-3, alpha=2.0, gamma=0.5):
        self.stp_MADS = StepwiseMADS(x0, bounds=bounds, delta0=delta0, delta_min=delta_min, alpha=alpha, gamma=gamma)
        self.candidates = None
        self.evaluations = []
        self.step_num = 0
        
    def step(self, evaluation):
        if self.candidates is None:
            # initial
            self.candidates = self.stp_MADS.get_next_candidate()
        elif self.candidates == []:
            # finish one iter
            print("pending_eval", self.stp_MADS.pending_eval)
            self.stp_MADS.update_with_result(self.evaluations)
            self.candidates = self.stp_MADS.get_next_candidate()
            self.evaluations = []
        
        self.evaluations.append(evaluation)    
        x = self.candidates.pop(0)
        self.step_num+=1
        return x

# %%
# Example Usage
def obj_func(x):
    a, b, c = x
    return (a - 0.5)**2 + (b - 15)**2 + (c - 1.5)**2  # Example function

bounds = np.array([[0, 1], [10, 20], [0, 3]])

x0=[0.9, 19, 0.1]
mads01 = MADS(x0, bounds=bounds)

# %%
# x = mads01.step(math.inf)

for _ in range(500):
    eval = obj_func(x0)
    
    x0 = mads01.step(eval)
    print("eval", _, eval, x0)
    # print("self.stp_MADS.pending_eval", mads01.stp_MADS.pending_eval)
    print("mads01.x", mads01.stp_MADS.x)
    print("mads01.candidates", mads01.candidates)
    print("mads01.evaluations", mads01.evaluations)
# Out:
# eval 0 18.12 [ 1.  19.   0.1]
# mads01.x [ 0.9 19.   0.1]
# mads01.candidates [array([ 0.9, 20. ,  0.1]), array([ 0.9, 19. ,  1.1]), array([ 0. , 19. ,  0.1]), array([ 0.9, 18. ,  0.1]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [18.12]
# eval 1 18.21 [ 0.9 20.   0.1]
# mads01.x [ 0.9 19.   0.1]
# mads01.candidates [array([ 0.9, 19. ,  1.1]), array([ 0. , 19. ,  0.1]), array([ 0.9, 18. ,  0.1]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [18.12, np.float64(18.21)]
# eval 2 27.12 [ 0.9 19.   1.1]
# mads01.x [ 0.9 19.   0.1]
# mads01.candidates [array([ 0. , 19. ,  0.1]), array([ 0.9, 18. ,  0.1]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [18.12, np.float64(18.21), np.float64(27.12)]
# eval 3 16.32 [ 0.  19.   0.1]
# mads01.x [ 0.9 19.   0.1]
# mads01.candidates [array([ 0.9, 18. ,  0.1]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [18.12, np.float64(18.21), np.float64(27.12), np.float64(16.32)]
# eval 4 18.21 [ 0.9 18.   0.1]
# mads01.x [ 0.9 19.   0.1]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [18.12, np.float64(18.21), np.float64(27.12), np.float64(16.32), np.float64(18.21)]
# eval 5 11.12 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0.1]
# mads01.candidates []
# mads01.evaluations [18.12, np.float64(18.21), np.float64(27.12), np.float64(16.32), np.float64(18.21), np.float64(11.12)]
# pending_eval [array([ 1. , 19. ,  0.1]), array([ 0.9, 20. ,  0.1]), array([ 0.9, 19. ,  1.1]), array([ 0. , 19. ,  0.1]), array([ 0.9, 18. ,  0.1]), array([ 0.9, 19. ,  0. ])]
# eval 6 18.41 [ 1. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 20. ,  0. ]), array([ 0.9, 19. ,  2. ]), array([ 0., 19.,  0.]), array([ 0.9, 17. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 7 18.5 [ 0.9 20.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  2. ]), array([ 0., 19.,  0.]), array([ 0.9, 17. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5)]
# eval 8 27.41 [ 0.9 19.   2. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0., 19.,  0.]), array([ 0.9, 17. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41)]
# eval 9 16.41 [ 0. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 17. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(16.41)]
# eval 10 18.5 [ 0.9 17.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(16.41), np.float64(18.5)]
# eval 11 6.41 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(16.41), np.float64(18.5), np.float64(6.41)]
# pending_eval [array([ 1., 19.,  0.]), array([ 0.9, 20. ,  0. ]), array([ 0.9, 19. ,  2. ]), array([ 0., 19.,  0.]), array([ 0.9, 17. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# eval 12 18.41 [ 1. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 20. ,  0. ]), array([ 0.9, 19. ,  3. ]), array([ 0., 19.,  0.]), array([ 0.9, 15. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 13 18.5 [ 0.9 20.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  3. ]), array([ 0., 19.,  0.]), array([ 0.9, 15. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5)]
# eval 14 27.41 [ 0.9 19.   3. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0., 19.,  0.]), array([ 0.9, 15. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41)]
# eval 15 18.41 [ 0. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 15. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(18.41)]
# eval 16 18.5 [ 0.9 15.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(18.41), np.float64(18.5)]
# eval 17 2.41 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(18.41), np.float64(18.5), np.float64(2.41)]
# pending_eval [array([ 1., 19.,  0.]), array([ 0.9, 20. ,  0. ]), array([ 0.9, 19. ,  3. ]), array([ 0., 19.,  0.]), array([ 0.9, 15. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# eval 18 18.41 [ 1. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 20. ,  0. ]), array([ 0.9, 19. ,  3. ]), array([ 0., 19.,  0.]), array([ 0.9, 11. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 19 18.5 [ 0.9 20.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  3. ]), array([ 0., 19.,  0.]), array([ 0.9, 11. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5)]
# eval 20 27.41 [ 0.9 19.   3. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0., 19.,  0.]), array([ 0.9, 11. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41)]
# eval 21 18.41 [ 0. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 11. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(18.41)]
# eval 22 18.5 [ 0.9 11.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(18.41), np.float64(18.5)]
# eval 23 18.41 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(18.41), np.float64(18.5), np.float64(18.41)]
# pending_eval [array([ 1., 19.,  0.]), array([ 0.9, 20. ,  0. ]), array([ 0.9, 19. ,  3. ]), array([ 0., 19.,  0.]), array([ 0.9, 11. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# eval 24 18.41 [ 1. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 20. ,  0. ]), array([ 0.9, 19. ,  3. ]), array([ 0., 19.,  0.]), array([ 0.9, 15. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 25 18.5 [ 0.9 20.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  3. ]), array([ 0., 19.,  0.]), array([ 0.9, 15. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5)]
# eval 26 27.41 [ 0.9 19.   3. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0., 19.,  0.]), array([ 0.9, 15. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41)]
# eval 27 18.41 [ 0. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 15. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(18.41)]
# eval 28 18.5 [ 0.9 15.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(18.41), np.float64(18.5)]
# eval 29 2.41 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(18.41), np.float64(18.5), np.float64(2.41)]
# pending_eval [array([ 1., 19.,  0.]), array([ 0.9, 20. ,  0. ]), array([ 0.9, 19. ,  3. ]), array([ 0., 19.,  0.]), array([ 0.9, 15. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# eval 30 18.41 [ 1. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 20. ,  0. ]), array([ 0.9, 19. ,  2. ]), array([ 0., 19.,  0.]), array([ 0.9, 17. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 31 18.5 [ 0.9 20.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  2. ]), array([ 0., 19.,  0.]), array([ 0.9, 17. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5)]
# eval 32 27.41 [ 0.9 19.   2. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0., 19.,  0.]), array([ 0.9, 17. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41)]
# eval 33 16.41 [ 0. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 17. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(16.41)]
# eval 34 18.5 [ 0.9 17.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(16.41), np.float64(18.5)]
# eval 35 6.41 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(16.41), np.float64(18.5), np.float64(6.41)]
# pending_eval [array([ 1., 19.,  0.]), array([ 0.9, 20. ,  0. ]), array([ 0.9, 19. ,  2. ]), array([ 0., 19.,  0.]), array([ 0.9, 17. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# eval 36 18.41 [ 1. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 20. ,  0. ]), array([ 0.9, 19. ,  1. ]), array([ 0., 19.,  0.]), array([ 0.9, 18. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 37 18.5 [ 0.9 20.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  1. ]), array([ 0., 19.,  0.]), array([ 0.9, 18. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5)]
# eval 38 27.41 [ 0.9 19.   1. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0., 19.,  0.]), array([ 0.9, 18. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41)]
# eval 39 16.41 [ 0. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 18. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(16.41)]
# eval 40 18.5 [ 0.9 18.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(16.41), np.float64(18.5)]
# eval 41 11.41 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(27.41), np.float64(16.41), np.float64(18.5), np.float64(11.41)]
# pending_eval [array([ 1., 19.,  0.]), array([ 0.9, 20. ,  0. ]), array([ 0.9, 19. ,  1. ]), array([ 0., 19.,  0.]), array([ 0.9, 18. ,  0. ]), array([ 0.9, 19. ,  0. ])]
# eval 42 18.41 [ 1. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19.5,  0. ]), array([ 0.9, 19. ,  0.5]), array([ 0.4, 19. ,  0. ]), array([ 0.9, 18.5,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 43 18.5 [ 0.9 19.5  0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0.5]), array([ 0.4, 19. ,  0. ]), array([ 0.9, 18.5,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5)]
# eval 44 22.66 [ 0.9 19.   0.5]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.4, 19. ,  0. ]), array([ 0.9, 18.5,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(22.66)]
# eval 45 17.16 [ 0.4 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 18.5,  0. ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(22.66), np.float64(17.16)]
# eval 46 18.26 [ 0.9 18.5  0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(22.66), np.float64(17.16), np.float64(18.26)]
# eval 47 14.66 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(22.66), np.float64(17.16), np.float64(18.26), np.float64(14.66)]
# pending_eval [array([ 1., 19.,  0.]), array([ 0.9, 19.5,  0. ]), array([ 0.9, 19. ,  0.5]), array([ 0.4, 19. ,  0. ]), array([ 0.9, 18.5,  0. ]), array([ 0.9, 19. ,  0. ])]
# eval 48 18.41 [ 1. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9 , 19.25,  0.  ]), array([ 0.9 , 19.  ,  0.25]), array([ 0.65, 19.  ,  0.  ]), array([ 0.9 , 18.75,  0.  ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 49 18.5 [ 0.9  19.25  0.  ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9 , 19.  ,  0.25]), array([ 0.65, 19.  ,  0.  ]), array([ 0.9 , 18.75,  0.  ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5)]
# eval 50 20.4725 [ 0.9  19.    0.25]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.65, 19.  ,  0.  ]), array([ 0.9 , 18.75,  0.  ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(20.4725)]
# eval 51 17.7225 [ 0.65 19.    0.  ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9 , 18.75,  0.  ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(20.4725), np.float64(17.7225)]
# eval 52 18.2725 [ 0.9  18.75  0.  ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(20.4725), np.float64(17.7225), np.float64(18.2725)]
# eval 53 16.4725 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(20.4725), np.float64(17.7225), np.float64(18.2725), np.float64(16.4725)]
# pending_eval [array([ 1., 19.,  0.]), array([ 0.9 , 19.25,  0.  ]), array([ 0.9 , 19.  ,  0.25]), array([ 0.65, 19.  ,  0.  ]), array([ 0.9 , 18.75,  0.  ]), array([ 0.9, 19. ,  0. ])]
# eval 54 18.41 [ 1. 19.  0.]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.125,  0.   ]), array([ 0.9  , 19.   ,  0.125]), array([ 0.775, 19.   ,  0.   ]), array([ 0.9  , 18.875,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 55 18.5 [ 0.9   19.125  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.   ,  0.125]), array([ 0.775, 19.   ,  0.   ]), array([ 0.9  , 18.875,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5)]
# eval 56 19.425625 [ 0.9   19.     0.125]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.775, 19.   ,  0.   ]), array([ 0.9  , 18.875,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(19.425625)]
# eval 57 18.050625 [ 0.775 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.875,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(19.425625), np.float64(18.050625)]
# eval 58 18.325625 [ 0.9   18.875  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(19.425625), np.float64(18.050625), np.float64(18.325625)]
# eval 59 17.425625 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.5), np.float64(19.425625), np.float64(18.050625), np.float64(18.325625), np.float64(17.425625)]
# pending_eval [array([ 1., 19.,  0.]), array([ 0.9  , 19.125,  0.   ]), array([ 0.9  , 19.   ,  0.125]), array([ 0.775, 19.   ,  0.   ]), array([ 0.9  , 18.875,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 60 18.41 [ 0.9625 19.      0.    ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9   , 19.0625,  0.    ]), array([ 0.9   , 19.    ,  0.0625]), array([ 0.8375, 19.    ,  0.    ]), array([ 0.9   , 18.9375,  0.    ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 61 18.46390625 [ 0.9    19.0625  0.    ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9   , 19.    ,  0.0625]), array([ 0.8375, 19.    ,  0.    ]), array([ 0.9   , 18.9375,  0.    ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.46390625)]
# eval 62 18.91390625 [ 0.9    19.      0.0625]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.8375, 19.    ,  0.    ]), array([ 0.9   , 18.9375,  0.    ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.46390625), np.float64(18.91390625)]
# eval 63 18.22640625 [ 0.8375 19.      0.    ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9   , 18.9375,  0.    ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.46390625), np.float64(18.91390625), np.float64(18.22640625)]
# eval 64 18.36390625 [ 0.9    18.9375  0.    ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.46390625), np.float64(18.91390625), np.float64(18.22640625), np.float64(18.36390625)]
# eval 65 17.91390625 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.46390625), np.float64(18.91390625), np.float64(18.22640625), np.float64(18.36390625), np.float64(17.91390625)]
# pending_eval [array([ 0.9625, 19.    ,  0.    ]), array([ 0.9   , 19.0625,  0.    ]), array([ 0.9   , 19.    ,  0.0625]), array([ 0.8375, 19.    ,  0.    ]), array([ 0.9   , 18.9375,  0.    ]), array([ 0.9, 19. ,  0. ])]
# eval 66 18.41 [ 0.93125 19.       0.     ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9    , 19.03125,  0.     ]), array([ 0.9    , 19.     ,  0.03125]), array([ 0.86875, 19.     ,  0.     ]), array([ 0.9    , 18.96875,  0.     ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 67 18.4359765625 [ 0.9     19.03125  0.     ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9    , 19.     ,  0.03125]), array([ 0.86875, 19.     ,  0.     ]), array([ 0.9    , 18.96875,  0.     ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.4359765625)]
# eval 68 18.6609765625 [ 0.9     19.       0.03125]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.86875, 19.     ,  0.     ]), array([ 0.9    , 18.96875,  0.     ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.4359765625), np.float64(18.6609765625)]
# eval 69 18.3172265625 [ 0.86875 19.       0.     ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9    , 18.96875,  0.     ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.4359765625), np.float64(18.6609765625), np.float64(18.3172265625)]
# eval 70 18.3859765625 [ 0.9     18.96875  0.     ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.4359765625), np.float64(18.6609765625), np.float64(18.3172265625), np.float64(18.3859765625)]
# eval 71 18.1609765625 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.4359765625), np.float64(18.6609765625), np.float64(18.3172265625), np.float64(18.3859765625), np.float64(18.1609765625)]
# pending_eval [array([ 0.93125, 19.     ,  0.     ]), array([ 0.9    , 19.03125,  0.     ]), array([ 0.9    , 19.     ,  0.03125]), array([ 0.86875, 19.     ,  0.     ]), array([ 0.9    , 18.96875,  0.     ]), array([ 0.9, 19. ,  0. ])]
# eval 72 18.41 [ 0.915625 19.        0.      ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9     , 19.015625,  0.      ]), array([9.0000e-01, 1.9000e+01, 1.5625e-02]), array([ 0.884375, 19.      ,  0.      ]), array([ 0.9     , 18.984375,  0.      ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 73 18.422744140625 [ 0.9      19.015625  0.      ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0000e-01, 1.9000e+01, 1.5625e-02]), array([ 0.884375, 19.      ,  0.      ]), array([ 0.9     , 18.984375,  0.      ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.422744140625)]
# eval 74 18.535244140625 [9.0000e-01 1.9000e+01 1.5625e-02]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.884375, 19.      ,  0.      ]), array([ 0.9     , 18.984375,  0.      ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.422744140625), np.float64(18.535244140625)]
# eval 75 18.363369140625 [ 0.884375 19.        0.      ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9     , 18.984375,  0.      ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.422744140625), np.float64(18.535244140625), np.float64(18.363369140625)]
# eval 76 18.397744140625 [ 0.9      18.984375  0.      ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.422744140625), np.float64(18.535244140625), np.float64(18.363369140625), np.float64(18.397744140625)]
# eval 77 18.285244140625 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.422744140625), np.float64(18.535244140625), np.float64(18.363369140625), np.float64(18.397744140625), np.float64(18.285244140625)]
# pending_eval [array([ 0.915625, 19.      ,  0.      ]), array([ 0.9     , 19.015625,  0.      ]), array([9.0000e-01, 1.9000e+01, 1.5625e-02]), array([ 0.884375, 19.      ,  0.      ]), array([ 0.9     , 18.984375,  0.      ]), array([ 0.9, 19. ,  0. ])]
# eval 78 18.41 [ 0.9078125 19.         0.       ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9      , 19.0078125,  0.       ]), array([9.0000e-01, 1.9000e+01, 7.8125e-03]), array([ 0.8921875, 19.       ,  0.       ]), array([ 0.9      , 18.9921875,  0.       ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 79 18.41631103515625 [ 0.9       19.0078125  0.       ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0000e-01, 1.9000e+01, 7.8125e-03]), array([ 0.8921875, 19.       ,  0.       ]), array([ 0.9      , 18.9921875,  0.       ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.41631103515625)]
# eval 80 18.47256103515625 [9.0000e-01 1.9000e+01 7.8125e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.8921875, 19.       ,  0.       ]), array([ 0.9      , 18.9921875,  0.       ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.41631103515625), np.float64(18.47256103515625)]
# eval 81 18.38662353515625 [ 0.8921875 19.         0.       ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9      , 18.9921875,  0.       ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.41631103515625), np.float64(18.47256103515625), np.float64(18.38662353515625)]
# eval 82 18.40381103515625 [ 0.9       18.9921875  0.       ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.41631103515625), np.float64(18.47256103515625), np.float64(18.38662353515625), np.float64(18.40381103515625)]
# eval 83 18.34756103515625 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.41631103515625), np.float64(18.47256103515625), np.float64(18.38662353515625), np.float64(18.40381103515625), np.float64(18.34756103515625)]
# pending_eval [array([ 0.9078125, 19.       ,  0.       ]), array([ 0.9      , 19.0078125,  0.       ]), array([9.0000e-01, 1.9000e+01, 7.8125e-03]), array([ 0.8921875, 19.       ,  0.       ]), array([ 0.9      , 18.9921875,  0.       ]), array([ 0.9, 19. ,  0. ])]
# eval 84 18.41 [ 0.90390625 19.          0.        ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9       , 19.00390625,  0.        ]), array([9.00000e-01, 1.90000e+01, 3.90625e-03]), array([ 0.89609375, 19.        ,  0.        ]), array([ 0.9       , 18.99609375,  0.        ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 85 18.413140258789063 [ 0.9        19.00390625  0.        ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.00000e-01, 1.90000e+01, 3.90625e-03]), array([ 0.89609375, 19.        ,  0.        ]), array([ 0.9       , 18.99609375,  0.        ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.413140258789063)]
# eval 86 18.441265258789063 [9.00000e-01 1.90000e+01 3.90625e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.89609375, 19.        ,  0.        ]), array([ 0.9       , 18.99609375,  0.        ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.413140258789063), np.float64(18.441265258789063)]
# eval 87 18.398296508789063 [ 0.89609375 19.          0.        ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9       , 18.99609375,  0.        ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.413140258789063), np.float64(18.441265258789063), np.float64(18.398296508789063)]
# eval 88 18.406890258789062 [ 0.9        18.99609375  0.        ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.413140258789063), np.float64(18.441265258789063), np.float64(18.398296508789063), np.float64(18.406890258789062)]
# eval 89 18.378765258789063 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.413140258789063), np.float64(18.441265258789063), np.float64(18.398296508789063), np.float64(18.406890258789062), np.float64(18.378765258789063)]
# pending_eval [array([ 0.90390625, 19.        ,  0.        ]), array([ 0.9       , 19.00390625,  0.        ]), array([9.00000e-01, 1.90000e+01, 3.90625e-03]), array([ 0.89609375, 19.        ,  0.        ]), array([ 0.9       , 18.99609375,  0.        ]), array([ 0.9, 19. ,  0. ])]
# eval 90 18.41 [ 0.90195313 19.          0.        ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9       , 19.00195312,  0.        ]), array([9.000000e-01, 1.900000e+01, 1.953125e-03]), array([ 0.89804688, 19.        ,  0.        ]), array([ 0.9       , 18.99804688,  0.        ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 91 18.411566314697264 [ 0.9        19.00195312  0.        ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.000000e-01, 1.900000e+01, 1.953125e-03]), array([ 0.89804688, 19.        ,  0.        ]), array([ 0.9       , 18.99804688,  0.        ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.411566314697264)]
# eval 92 18.425628814697266 [9.000000e-01 1.900000e+01 1.953125e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.89804688, 19.        ,  0.        ]), array([ 0.9       , 18.99804688,  0.        ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.411566314697264), np.float64(18.425628814697266)]
# eval 93 18.404144439697266 [ 0.89804688 19.          0.        ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9       , 18.99804688,  0.        ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.411566314697264), np.float64(18.425628814697266), np.float64(18.404144439697266)]
# eval 94 18.408441314697267 [ 0.9        18.99804688  0.        ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.411566314697264), np.float64(18.425628814697266), np.float64(18.404144439697266), np.float64(18.408441314697267)]
# eval 95 18.394378814697266 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.411566314697264), np.float64(18.425628814697266), np.float64(18.404144439697266), np.float64(18.408441314697267), np.float64(18.394378814697266)]
# pending_eval [array([ 0.90195313, 19.        ,  0.        ]), array([ 0.9       , 19.00195312,  0.        ]), array([9.000000e-01, 1.900000e+01, 1.953125e-03]), array([ 0.89804688, 19.        ,  0.        ]), array([ 0.9       , 18.99804688,  0.        ]), array([ 0.9, 19. ,  0. ])]
# eval 96 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 97 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 98 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 99 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 100 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 101 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 102 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 103 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 104 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 105 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 106 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 107 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 108 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 109 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 110 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 111 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 112 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 113 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 114 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 115 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 116 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 117 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 118 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 119 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 120 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 121 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 122 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 123 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 124 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 125 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 126 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 127 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 128 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 129 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 130 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 131 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 132 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 133 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 134 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 135 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 136 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 137 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 138 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 139 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 140 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 141 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 142 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 143 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 144 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 145 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 146 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 147 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 148 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 149 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 150 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 151 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 152 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 153 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 154 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 155 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 156 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 157 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 158 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 159 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 160 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 161 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# ...
# eval 448 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 449 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 450 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 451 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 452 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 453 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 454 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 455 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 456 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 457 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 458 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 459 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 460 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 461 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 462 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 463 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 464 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 465 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 466 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 467 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 468 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 469 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 470 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 471 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 472 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 473 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 474 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 475 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 476 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 477 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 478 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 479 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 480 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 481 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 482 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 483 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 484 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 485 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 486 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 487 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 488 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 489 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 490 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 491 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 492 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 493 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]
# eval 494 18.41800100000001 [9.0e-01 1.9e+01 1.0e-03]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001)]
# eval 495 18.407001 [ 0.899 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001)]
# eval 496 18.409201 [ 0.9   18.999  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201)]
# eval 497 18.402000999999988 [ 0.9 19.   0. ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates []
# mads01.evaluations [np.float64(18.41), np.float64(18.410801), np.float64(18.41800100000001), np.float64(18.407001), np.float64(18.409201), np.float64(18.402000999999988)]
# pending_eval [array([ 0.901, 19.   ,  0.   ]), array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# eval 498 18.41 [ 0.901 19.     0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([ 0.9  , 19.001,  0.   ]), array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41)]
# eval 499 18.410801 [ 0.9   19.001  0.   ]
# mads01.x [ 0.9 19.   0. ]
# mads01.candidates [array([9.0e-01, 1.9e+01, 1.0e-03]), array([ 0.899, 19.   ,  0.   ]), array([ 0.9  , 18.999,  0.   ]), array([ 0.9, 19. ,  0. ])]
# mads01.evaluations [np.float64(18.41), np.float64(18.410801)]

# %%
class MADS_old:
    def __init__(self, x0, bounds, delta0=1.0, delta_min=1e-3, alpha=2.0, gamma=0.5):
        self.stp_MADS = StepwiseMADS(x0, bounds=bounds, delta0=delta0, delta_min=delta_min, alpha=alpha, gamma=gamma)
        self.candidates = []
        self.evaluations = []
        self.step_num = 0
        
    def step(self, evaluation):
        if len(self.candidates) == 0:
            print("self can 0")
            if self.evaluations!=[]:
                self.stp_MADS.update_with_result(self.evaluations)
                self.evaluations = []
                self.candidates = self.stp_MADS.get_next_candidate()
                print("self.candidates", self.candidates)
            else:
                print("self can 1")
                
                self.candidates = self.stp_MADS.get_next_candidate()
        else:
            pass
            

        self.evaluations.append(evaluation)
            
        x = self.candidates.pop(0)
        return x
