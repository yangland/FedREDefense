# %%
import numpy as np

class StepwiseMADS:
    def __init__(self, x0, bounds, delta0=1.0, delta_min=1e-3, alpha=2.0, gamma=0.5):
        self.x = np.array(x0)
        self.bounds = np.array(bounds)
        self.delta = delta0
        self.delta_min = delta_min
        self.alpha = alpha
        self.gamma = gamma
        self.mesh_size = delta0
        self.iteration = 0
        self.pending_eval = None
        self.best_value = None  # Store the best evaluation value
    
    def get_next_candidate(self):
        if self.pending_eval is not None:
            raise RuntimeError("Previous evaluation result is still pending.")
        
        directions = np.eye(len(self.x))
        candidates = [self.x + self.mesh_size * d for d in directions] + [self.x - self.mesh_size * d for d in directions]
        
        candidates = [np.clip(c, self.bounds[:, 0], self.bounds[:, 1]) for c in candidates]
        self.pending_eval = candidates.copy()
        return candidates
    
    def update_with_result(self, evaluations):
        if self.pending_eval is None:
            raise RuntimeError("No pending evaluations to update with.")
        
        best_idx = np.argmin(evaluations)
        best_candidate = self.pending_eval[best_idx]
        best_value = evaluations[best_idx]
        
        if self.best_value is None or best_value < self.best_value:
            self.x = best_candidate
            self.best_value = best_value
            self.mesh_size *= self.alpha
        else:
            self.mesh_size *= self.gamma
        
        self.mesh_size = max(self.mesh_size, self.delta_min)
        self.pending_eval = None
        self.iteration += 1
    
    def get_current_solution(self):
        return self.x

# %%
# Example Usage
def obj_func(x):
    a, b, c = x
    return (a - 0.5)**2 + (b - 15)**2 + (c - 1.5)**2  # Example function

bounds = np.array([[0, 1], [10, 20], [0, 3]])
mads = StepwiseMADS(x0=[0.9, 19, 0.1], bounds=bounds)
mads.best_value = obj_func(mads.x)  # Initialize best value with initial point evaluation
print("initial best value", mads.best_value)

for _ in range(20):  # Run for a few iterations
    candidates = mads.get_next_candidate()
    print("candidates:", candidates)
    evaluations = [float(obj_func(c)) for c in candidates]  # Simulated evaluation
    print("evaluations:", evaluations)
    mads.update_with_result(evaluations)
    print(f"Iter {_}candidates, evaluations", list(zip(candidates, evaluations)))
    print("current solution", mads.get_current_solution())
    print(f"Iteration {_}: Best solution {mads.get_current_solution()} with value {mads.best_value}")
# Out:
# initial best value 18.12
# candidates: [array([ 1. , 19. ,  0.1]), array([ 0.9, 20. ,  0.1]), array([ 0.9, 19. ,  1.1]), array([ 0. , 19. ,  0.1]), array([ 0.9, 18. ,  0.1]), array([ 0.9, 19. ,  0. ])]
# evaluations: [18.21, 27.12, 16.32, 18.21, 11.12, 18.41]
# Iter 0candidates, evaluations [(array([ 1. , 19. ,  0.1]), 18.21), (array([ 0.9, 20. ,  0.1]), 27.12), (array([ 0.9, 19. ,  1.1]), 16.32), (array([ 0. , 19. ,  0.1]), 18.21), (array([ 0.9, 18. ,  0.1]), 11.12), (array([ 0.9, 19. ,  0. ]), 18.41)]
# current solution [ 0.9 18.   0.1]
# Iteration 0: Best solution [ 0.9 18.   0.1] with value 11.12
# candidates: [array([ 1. , 18. ,  0.1]), array([ 0.9, 20. ,  0.1]), array([ 0.9, 18. ,  2.1]), array([ 0. , 18. ,  0.1]), array([ 0.9, 16. ,  0.1]), array([ 0.9, 18. ,  0. ])]
# evaluations: [11.209999999999999, 27.12, 9.52, 11.209999999999999, 3.12, 11.41]
# Iter 1candidates, evaluations [(array([ 1. , 18. ,  0.1]), 11.209999999999999), (array([ 0.9, 20. ,  0.1]), 27.12), (array([ 0.9, 18. ,  2.1]), 9.52), (array([ 0. , 18. ,  0.1]), 11.209999999999999), (array([ 0.9, 16. ,  0.1]), 3.12), (array([ 0.9, 18. ,  0. ]), 11.41)]
# current solution [ 0.9 16.   0.1]
# Iteration 1: Best solution [ 0.9 16.   0.1] with value 3.12
# candidates: [array([ 1. , 16. ,  0.1]), array([ 0.9, 20. ,  0.1]), array([ 0.9, 16. ,  3. ]), array([ 0. , 16. ,  0.1]), array([ 0.9, 12. ,  0.1]), array([ 0.9, 16. ,  0. ])]
# evaluations: [3.21, 27.12, 3.41, 3.21, 11.12, 3.41]
# Iter 2candidates, evaluations [(array([ 1. , 16. ,  0.1]), 3.21), (array([ 0.9, 20. ,  0.1]), 27.12), (array([ 0.9, 16. ,  3. ]), 3.41), (array([ 0. , 16. ,  0.1]), 3.21), (array([ 0.9, 12. ,  0.1]), 11.12), (array([ 0.9, 16. ,  0. ]), 3.41)]
# current solution [ 0.9 16.   0.1]
# Iteration 2: Best solution [ 0.9 16.   0.1] with value 3.12
# candidates: [array([ 1. , 16. ,  0.1]), array([ 0.9, 18. ,  0.1]), array([ 0.9, 16. ,  2.1]), array([ 0. , 16. ,  0.1]), array([ 0.9, 14. ,  0.1]), array([ 0.9, 16. ,  0. ])]
# evaluations: [3.21, 11.12, 1.5200000000000002, 3.21, 3.12, 3.41]
# Iter 3candidates, evaluations [(array([ 1. , 16. ,  0.1]), 3.21), (array([ 0.9, 18. ,  0.1]), 11.12), (array([ 0.9, 16. ,  2.1]), 1.5200000000000002), (array([ 0. , 16. ,  0.1]), 3.21), (array([ 0.9, 14. ,  0.1]), 3.12), (array([ 0.9, 16. ,  0. ]), 3.41)]
# current solution [ 0.9 16.   2.1]
# Iteration 3: Best solution [ 0.9 16.   2.1] with value 1.5200000000000002
# candidates: [array([ 1. , 16. ,  2.1]), array([ 0.9, 20. ,  2.1]), array([ 0.9, 16. ,  3. ]), array([ 0. , 16. ,  2.1]), array([ 0.9, 12. ,  2.1]), array([ 0.9, 16. ,  0. ])]
# evaluations: [1.61, 25.52, 3.41, 1.61, 9.52, 3.41]
# Iter 4candidates, evaluations [(array([ 1. , 16. ,  2.1]), 1.61), (array([ 0.9, 20. ,  2.1]), 25.52), (array([ 0.9, 16. ,  3. ]), 3.41), (array([ 0. , 16. ,  2.1]), 1.61), (array([ 0.9, 12. ,  2.1]), 9.52), (array([ 0.9, 16. ,  0. ]), 3.41)]
# current solution [ 0.9 16.   2.1]
# Iteration 4: Best solution [ 0.9 16.   2.1] with value 1.5200000000000002
# candidates: [array([ 1. , 16. ,  2.1]), array([ 0.9, 18. ,  2.1]), array([ 0.9, 16. ,  3. ]), array([ 0. , 16. ,  2.1]), array([ 0.9, 14. ,  2.1]), array([ 0.9, 16. ,  0.1])]
# evaluations: [1.61, 9.52, 3.41, 1.61, 1.5200000000000002, 3.12]
# Iter 5candidates, evaluations [(array([ 1. , 16. ,  2.1]), 1.61), (array([ 0.9, 18. ,  2.1]), 9.52), (array([ 0.9, 16. ,  3. ]), 3.41), (array([ 0. , 16. ,  2.1]), 1.61), (array([ 0.9, 14. ,  2.1]), 1.5200000000000002), (array([ 0.9, 16. ,  0.1]), 3.12)]
# current solution [ 0.9 16.   2.1]
# Iteration 5: Best solution [ 0.9 16.   2.1] with value 1.5200000000000002
# candidates: [array([ 1. , 16. ,  2.1]), array([ 0.9, 17. ,  2.1]), array([ 0.9, 16. ,  3. ]), array([ 0. , 16. ,  2.1]), array([ 0.9, 15. ,  2.1]), array([ 0.9, 16. ,  1.1])]
# evaluations: [1.61, 4.5200000000000005, 3.41, 1.61, 0.5200000000000001, 1.32]
# Iter 6candidates, evaluations [(array([ 1. , 16. ,  2.1]), 1.61), (array([ 0.9, 17. ,  2.1]), 4.5200000000000005), (array([ 0.9, 16. ,  3. ]), 3.41), (array([ 0. , 16. ,  2.1]), 1.61), (array([ 0.9, 15. ,  2.1]), 0.5200000000000001), (array([ 0.9, 16. ,  1.1]), 1.32)]
# current solution [ 0.9 15.   2.1]
# Iteration 6: Best solution [ 0.9 15.   2.1] with value 0.5200000000000001
# candidates: [array([ 1. , 15. ,  2.1]), array([ 0.9, 17. ,  2.1]), array([ 0.9, 15. ,  3. ]), array([ 0. , 15. ,  2.1]), array([ 0.9, 13. ,  2.1]), array([ 0.9, 15. ,  0.1])]
# evaluations: [0.6100000000000001, 4.5200000000000005, 2.41, 0.6100000000000001, 4.5200000000000005, 2.1199999999999997]
# Iter 7candidates, evaluations [(array([ 1. , 15. ,  2.1]), 0.6100000000000001), (array([ 0.9, 17. ,  2.1]), 4.5200000000000005), (array([ 0.9, 15. ,  3. ]), 2.41), (array([ 0. , 15. ,  2.1]), 0.6100000000000001), (array([ 0.9, 13. ,  2.1]), 4.5200000000000005), (array([ 0.9, 15. ,  0.1]), 2.1199999999999997)]
# current solution [ 0.9 15.   2.1]
# Iteration 7: Best solution [ 0.9 15.   2.1] with value 0.5200000000000001
# candidates: [array([ 1. , 15. ,  2.1]), array([ 0.9, 16. ,  2.1]), array([ 0.9, 15. ,  3. ]), array([ 0. , 15. ,  2.1]), array([ 0.9, 14. ,  2.1]), array([ 0.9, 15. ,  1.1])]
# evaluations: [0.6100000000000001, 1.5200000000000002, 2.41, 0.6100000000000001, 1.5200000000000002, 0.31999999999999995]
# Iter 8candidates, evaluations [(array([ 1. , 15. ,  2.1]), 0.6100000000000001), (array([ 0.9, 16. ,  2.1]), 1.5200000000000002), (array([ 0.9, 15. ,  3. ]), 2.41), (array([ 0. , 15. ,  2.1]), 0.6100000000000001), (array([ 0.9, 14. ,  2.1]), 1.5200000000000002), (array([ 0.9, 15. ,  1.1]), 0.31999999999999995)]
# current solution [ 0.9 15.   1.1]
# Iteration 8: Best solution [ 0.9 15.   1.1] with value 0.31999999999999995
# candidates: [array([ 1. , 15. ,  1.1]), array([ 0.9, 17. ,  1.1]), array([ 0.9, 15. ,  3. ]), array([ 0. , 15. ,  1.1]), array([ 0.9, 13. ,  1.1]), array([ 0.9, 15. ,  0. ])]
# evaluations: [0.4099999999999999, 4.32, 2.41, 0.4099999999999999, 4.32, 2.41]
# Iter 9candidates, evaluations [(array([ 1. , 15. ,  1.1]), 0.4099999999999999), (array([ 0.9, 17. ,  1.1]), 4.32), (array([ 0.9, 15. ,  3. ]), 2.41), (array([ 0. , 15. ,  1.1]), 0.4099999999999999), (array([ 0.9, 13. ,  1.1]), 4.32), (array([ 0.9, 15. ,  0. ]), 2.41)]
# current solution [ 0.9 15.   1.1]
# Iteration 9: Best solution [ 0.9 15.   1.1] with value 0.31999999999999995
# candidates: [array([ 1. , 15. ,  1.1]), array([ 0.9, 16. ,  1.1]), array([ 0.9, 15. ,  2.1]), array([ 0. , 15. ,  1.1]), array([ 0.9, 14. ,  1.1]), array([ 0.9, 15. ,  0.1])]
# evaluations: [0.4099999999999999, 1.32, 0.5200000000000001, 0.4099999999999999, 1.32, 2.1199999999999997]
# Iter 10candidates, evaluations [(array([ 1. , 15. ,  1.1]), 0.4099999999999999), (array([ 0.9, 16. ,  1.1]), 1.32), (array([ 0.9, 15. ,  2.1]), 0.5200000000000001), (array([ 0. , 15. ,  1.1]), 0.4099999999999999), (array([ 0.9, 14. ,  1.1]), 1.32), (array([ 0.9, 15. ,  0.1]), 2.1199999999999997)]
# current solution [ 0.9 15.   1.1]
# Iteration 10: Best solution [ 0.9 15.   1.1] with value 0.31999999999999995
# candidates: [array([ 1. , 15. ,  1.1]), array([ 0.9, 15.5,  1.1]), array([ 0.9, 15. ,  1.6]), array([ 0.4, 15. ,  1.1]), array([ 0.9, 14.5,  1.1]), array([ 0.9, 15. ,  0.6])]
# evaluations: [0.4099999999999999, 0.57, 0.17000000000000004, 0.16999999999999993, 0.57, 0.9699999999999999]
# Iter 11candidates, evaluations [(array([ 1. , 15. ,  1.1]), 0.4099999999999999), (array([ 0.9, 15.5,  1.1]), 0.57), (array([ 0.9, 15. ,  1.6]), 0.17000000000000004), (array([ 0.4, 15. ,  1.1]), 0.16999999999999993), (array([ 0.9, 14.5,  1.1]), 0.57), (array([ 0.9, 15. ,  0.6]), 0.9699999999999999)]
# current solution [ 0.4 15.   1.1]
# Iteration 11: Best solution [ 0.4 15.   1.1] with value 0.16999999999999993
# candidates: [array([ 1. , 15. ,  1.1]), array([ 0.4, 16. ,  1.1]), array([ 0.4, 15. ,  2.1]), array([ 0. , 15. ,  1.1]), array([ 0.4, 14. ,  1.1]), array([ 0.4, 15. ,  0.1])]
# evaluations: [0.4099999999999999, 1.17, 0.3700000000000001, 0.4099999999999999, 1.17, 1.9699999999999998]
# Iter 12candidates, evaluations [(array([ 1. , 15. ,  1.1]), 0.4099999999999999), (array([ 0.4, 16. ,  1.1]), 1.17), (array([ 0.4, 15. ,  2.1]), 0.3700000000000001), (array([ 0. , 15. ,  1.1]), 0.4099999999999999), (array([ 0.4, 14. ,  1.1]), 1.17), (array([ 0.4, 15. ,  0.1]), 1.9699999999999998)]
# current solution [ 0.4 15.   1.1]
# Iteration 12: Best solution [ 0.4 15.   1.1] with value 0.16999999999999993
# candidates: [array([ 0.9, 15. ,  1.1]), array([ 0.4, 15.5,  1.1]), array([ 0.4, 15. ,  1.6]), array([ 0. , 15. ,  1.1]), array([ 0.4, 14.5,  1.1]), array([ 0.4, 15. ,  0.6])]
# evaluations: [0.31999999999999995, 0.41999999999999993, 0.02000000000000001, 0.4099999999999999, 0.41999999999999993, 0.8199999999999998]
# Iter 13candidates, evaluations [(array([ 0.9, 15. ,  1.1]), 0.31999999999999995), (array([ 0.4, 15.5,  1.1]), 0.41999999999999993), (array([ 0.4, 15. ,  1.6]), 0.02000000000000001), (array([ 0. , 15. ,  1.1]), 0.4099999999999999), (array([ 0.4, 14.5,  1.1]), 0.41999999999999993), (array([ 0.4, 15. ,  0.6]), 0.8199999999999998)]
# current solution [ 0.4 15.   1.6]
# Iteration 13: Best solution [ 0.4 15.   1.6] with value 0.02000000000000001
# candidates: [array([ 1. , 15. ,  1.6]), array([ 0.4, 16. ,  1.6]), array([ 0.4, 15. ,  2.6]), array([ 0. , 15. ,  1.6]), array([ 0.4, 14. ,  1.6]), array([ 0.4, 15. ,  0.6])]
# evaluations: [0.26, 1.02, 1.2200000000000002, 0.26, 1.02, 0.8199999999999998]
# Iter 14candidates, evaluations [(array([ 1. , 15. ,  1.6]), 0.26), (array([ 0.4, 16. ,  1.6]), 1.02), (array([ 0.4, 15. ,  2.6]), 1.2200000000000002), (array([ 0. , 15. ,  1.6]), 0.26), (array([ 0.4, 14. ,  1.6]), 1.02), (array([ 0.4, 15. ,  0.6]), 0.8199999999999998)]
# current solution [ 0.4 15.   1.6]
# Iteration 14: Best solution [ 0.4 15.   1.6] with value 0.02000000000000001
# candidates: [array([ 0.9, 15. ,  1.6]), array([ 0.4, 15.5,  1.6]), array([ 0.4, 15. ,  2.1]), array([ 0. , 15. ,  1.6]), array([ 0.4, 14.5,  1.6]), array([ 0.4, 15. ,  1.1])]
# evaluations: [0.17000000000000004, 0.27, 0.3700000000000001, 0.26, 0.27, 0.16999999999999993]
# Iter 15candidates, evaluations [(array([ 0.9, 15. ,  1.6]), 0.17000000000000004), (array([ 0.4, 15.5,  1.6]), 0.27), (array([ 0.4, 15. ,  2.1]), 0.3700000000000001), (array([ 0. , 15. ,  1.6]), 0.26), (array([ 0.4, 14.5,  1.6]), 0.27), (array([ 0.4, 15. ,  1.1]), 0.16999999999999993)]
# current solution [ 0.4 15.   1.6]
# Iteration 15: Best solution [ 0.4 15.   1.6] with value 0.02000000000000001
# candidates: [array([ 0.65, 15.  ,  1.6 ]), array([ 0.4 , 15.25,  1.6 ]), array([ 0.4 , 15.  ,  1.85]), array([ 0.15, 15.  ,  1.6 ]), array([ 0.4 , 14.75,  1.6 ]), array([ 0.4 , 15.  ,  1.35])]
# evaluations: [0.03250000000000002, 0.08250000000000002, 0.13250000000000006, 0.1325, 0.08250000000000002, 0.03249999999999997]
# Iter 16candidates, evaluations [(array([ 0.65, 15.  ,  1.6 ]), 0.03250000000000002), (array([ 0.4 , 15.25,  1.6 ]), 0.08250000000000002), (array([ 0.4 , 15.  ,  1.85]), 0.13250000000000006), (array([ 0.15, 15.  ,  1.6 ]), 0.1325), (array([ 0.4 , 14.75,  1.6 ]), 0.08250000000000002), (array([ 0.4 , 15.  ,  1.35]), 0.03249999999999997)]
# current solution [ 0.4 15.   1.6]
# Iteration 16: Best solution [ 0.4 15.   1.6] with value 0.02000000000000001
# candidates: [array([ 0.525, 15.   ,  1.6  ]), array([ 0.4  , 15.125,  1.6  ]), array([ 0.4  , 15.   ,  1.725]), array([ 0.275, 15.   ,  1.6  ]), array([ 0.4  , 14.875,  1.6  ]), array([ 0.4  , 15.   ,  1.475])]
# evaluations: [0.010625000000000018, 0.03562500000000001, 0.06062500000000003, 0.060625000000000005, 0.03562500000000001, 0.01062499999999999]
# Iter 17candidates, evaluations [(array([ 0.525, 15.   ,  1.6  ]), 0.010625000000000018), (array([ 0.4  , 15.125,  1.6  ]), 0.03562500000000001), (array([ 0.4  , 15.   ,  1.725]), 0.06062500000000003), (array([ 0.275, 15.   ,  1.6  ]), 0.060625000000000005), (array([ 0.4  , 14.875,  1.6  ]), 0.03562500000000001), (array([ 0.4  , 15.   ,  1.475]), 0.01062499999999999)]
# current solution [ 0.4   15.     1.475]
# Iteration 17: Best solution [ 0.4   15.     1.475] with value 0.01062499999999999
# candidates: [array([ 0.65 , 15.   ,  1.475]), array([ 0.4  , 15.25 ,  1.475]), array([ 0.4  , 15.   ,  1.725]), array([ 0.15 , 15.   ,  1.475]), array([ 0.4  , 14.75 ,  1.475]), array([ 0.4  , 15.   ,  1.225])]
# evaluations: [0.023125000000000003, 0.073125, 0.06062500000000003, 0.12312499999999998, 0.073125, 0.08562499999999995]
# Iter 18candidates, evaluations [(array([ 0.65 , 15.   ,  1.475]), 0.023125000000000003), (array([ 0.4  , 15.25 ,  1.475]), 0.073125), (array([ 0.4  , 15.   ,  1.725]), 0.06062500000000003), (array([ 0.15 , 15.   ,  1.475]), 0.12312499999999998), (array([ 0.4  , 14.75 ,  1.475]), 0.073125), (array([ 0.4  , 15.   ,  1.225]), 0.08562499999999995)]
# current solution [ 0.4   15.     1.475]
# Iteration 18: Best solution [ 0.4   15.     1.475] with value 0.01062499999999999
# candidates: [array([ 0.525, 15.   ,  1.475]), array([ 0.4  , 15.125,  1.475]), array([ 0.4, 15. ,  1.6]), array([ 0.275, 15.   ,  1.475]), array([ 0.4  , 14.875,  1.475]), array([ 0.4 , 15.  ,  1.35])]
# evaluations: [0.0012499999999999968, 0.026249999999999992, 0.02000000000000001, 0.05124999999999998, 0.026249999999999992, 0.03249999999999997]
# Iter 19candidates, evaluations [(array([ 0.525, 15.   ,  1.475]), 0.0012499999999999968), (array([ 0.4  , 15.125,  1.475]), 0.026249999999999992), (array([ 0.4, 15. ,  1.6]), 0.02000000000000001), (array([ 0.275, 15.   ,  1.475]), 0.05124999999999998), (array([ 0.4  , 14.875,  1.475]), 0.026249999999999992), (array([ 0.4 , 15.  ,  1.35]), 0.03249999999999997)]
# current solution [ 0.525 15.     1.475]
# Iteration 19: Best solution [ 0.525 15.     1.475] with value 0.0012499999999999968
