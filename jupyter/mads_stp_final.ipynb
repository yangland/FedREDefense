# %%
import numpy as np

class StepwiseMADS:
    def __init__(self, x0, bounds, delta0=1.0, delta_min=1e-3, alpha=2.0, gamma=0.5):
        self.x = np.array(x0)
        self.bounds = np.array(bounds)
        self.delta = delta0
        self.delta_min = delta_min
        self.alpha = alpha
        self.gamma = gamma
        self.mesh_size = delta0
        self.iteration = 0
        self.pending_eval = None
        self.best_value = None  # Store the best evaluation value
    
    def get_next_candidate(self):
        if self.pending_eval is not None:
            raise RuntimeError("Previous evaluation result is still pending.")
        
        directions = np.eye(len(self.x))
        candidates = [self.x + self.mesh_size * d for d in directions] + [self.x - self.mesh_size * d for d in directions]
        
        candidates = [np.clip(c, self.bounds[:, 0], self.bounds[:, 1]) for c in candidates]
        self.pending_eval = candidates.copy()
        return candidates
    
    def update_with_result(self, evaluations):
        if self.pending_eval is None:
            raise RuntimeError("No pending evaluations to update with.")

        best_idx = np.argmin(evaluations)
        best_candidate = self.pending_eval[best_idx]
        best_value = evaluations[best_idx]

        
        if self.best_value is None or best_value < self.best_value:
            self.x = best_candidate
            self.best_value = best_value
            self.mesh_size *= self.alpha
        else:
            self.mesh_size *= self.gamma
        
        self.mesh_size = max(self.mesh_size, self.delta_min)
        self.pending_eval = None
        self.iteration += 1
    
    def get_current_solution(self):
        return self.x

# %% [markdown]
# ## Stp on every call

# %%
import math

class MADS:
    def __init__(self, x0, initial_value, bounds, delta0=1.0, delta_min=1e-3, alpha=2.0, gamma=0.5):
        self.stp_MADS = StepwiseMADS(x0, bounds=bounds, delta0=delta0, delta_min=delta_min, alpha=alpha, gamma=gamma)
        self.candidates = self.stp_MADS.get_next_candidate()
        self.evaluations = []
        self.step_num = 0
        self.stp_MADS.best_value = initial_value

    def step(self, evaluation):
        self.evaluations.append(evaluation)
        if self.candidates == []:
            # new MADS iteration
            print("no candidates...")
            self.stp_MADS.update_with_result(self.evaluations)
            self.candidates = self.stp_MADS.get_next_candidate()
            
            self.evaluations = []
        else:
            print("pending candidatas...")
        self.step_num +=1
        return self.candidates.pop(0)

# %%
# Example Usage
def obj_func(x):
    a, b, c = x
    return (a - 0.5)**2 + (b - 15)**2 + (c - 1.5)**2  # Example function

bounds = np.array([[0, 1], [10, 20], [0, 3]])
mads = StepwiseMADS(x0=[0.9, 19, 0.1], bounds=bounds)

# %%
x0=[0.9, 19, 0.1]
initial_value = obj_func(x0)
bounds = np.array([[0, 1], [10, 20], [0, 3]])
ab = MADS(x0, initial_value, bounds)

# %%
x = x0

# %%
for _ in range(120): 
    evaluation = obj_func(x)
    print(f"step {_}, current x {x}")
    x = ab.step(evaluation)
    print(f"step {_}, {evaluation}, next x, {x}")
    # print("ab.stp_MADS.pending_eval", ab.stp_MADS.pending_eval)
# Out:
# step 0, current x [0.9, 19, 0.1]
# pending candidatas...
# step 0, 18.12, next x, [ 1.  19.   0.1]
# step 1, current x [ 1.  19.   0.1]
# pending candidatas...
# step 1, 18.21, next x, [ 0.9 20.   0.1]
# step 2, current x [ 0.9 20.   0.1]
# pending candidatas...
# step 2, 27.12, next x, [ 0.9 19.   1.1]
# step 3, current x [ 0.9 19.   1.1]
# pending candidatas...
# step 3, 16.32, next x, [ 0.  19.   0.1]
# step 4, current x [ 0.  19.   0.1]
# pending candidatas...
# step 4, 18.21, next x, [ 0.9 18.   0.1]
# step 5, current x [ 0.9 18.   0.1]
# pending candidatas...
# step 5, 11.12, next x, [ 0.9 19.   0. ]
# step 6, current x [ 0.9 19.   0. ]
# no candidates...
# step 6, 18.41, next x, [ 1. 19.  0.]
# step 7, current x [ 1. 19.  0.]
# pending candidatas...
# step 7, 18.5, next x, [ 0.9 20.   0. ]
# step 8, current x [ 0.9 20.   0. ]
# pending candidatas...
# step 8, 27.41, next x, [ 0.9 19.   2. ]
# step 9, current x [ 0.9 19.   2. ]
# pending candidatas...
# step 9, 16.41, next x, [ 0. 19.  0.]
# step 10, current x [ 0. 19.  0.]
# pending candidatas...
# step 10, 18.5, next x, [ 0.9 17.   0. ]
# step 11, current x [ 0.9 17.   0. ]
# pending candidatas...
# step 11, 6.41, next x, [ 0.9 19.   0. ]
# step 12, current x [ 0.9 19.   0. ]
# no candidates...
# step 12, 18.41, next x, [ 1. 17.  0.]
# step 13, current x [ 1. 17.  0.]
# pending candidatas...
# step 13, 6.5, next x, [ 0.9 20.   0. ]
# step 14, current x [ 0.9 20.   0. ]
# pending candidatas...
# step 14, 27.41, next x, [ 0.9 17.   3. ]
# step 15, current x [ 0.9 17.   3. ]
# pending candidatas...
# step 15, 6.41, next x, [ 0. 17.  0.]
# step 16, current x [ 0. 17.  0.]
# pending candidatas...
# step 16, 6.5, next x, [ 0.9 13.   0. ]
# step 17, current x [ 0.9 13.   0. ]
# pending candidatas...
# step 17, 6.41, next x, [ 0.9 17.   0. ]
# step 18, current x [ 0.9 17.   0. ]
# no candidates...
# step 18, 6.41, next x, [ 1. 17.  0.]
# step 19, current x [ 1. 17.  0.]
# pending candidatas...
# step 19, 6.5, next x, [ 0.9 19.   0. ]
# step 20, current x [ 0.9 19.   0. ]
# pending candidatas...
# step 20, 18.41, next x, [ 0.9 17.   2. ]
# step 21, current x [ 0.9 17.   2. ]
# pending candidatas...
# step 21, 4.41, next x, [ 0. 17.  0.]
# step 22, current x [ 0. 17.  0.]
# pending candidatas...
# step 22, 6.5, next x, [ 0.9 15.   0. ]
# step 23, current x [ 0.9 15.   0. ]
# pending candidatas...
# step 23, 2.41, next x, [ 0.9 17.   0. ]
# step 24, current x [ 0.9 17.   0. ]
# no candidates...
# step 24, 6.41, next x, [ 1. 15.  0.]
# step 25, current x [ 1. 15.  0.]
# pending candidatas...
# step 25, 2.5, next x, [ 0.9 19.   0. ]
# step 26, current x [ 0.9 19.   0. ]
# pending candidatas...
# step 26, 18.41, next x, [ 0.9 15.   3. ]
# step 27, current x [ 0.9 15.   3. ]
# pending candidatas...
# step 27, 2.41, next x, [ 0. 15.  0.]
# step 28, current x [ 0. 15.  0.]
# pending candidatas...
# step 28, 2.5, next x, [ 0.9 11.   0. ]
# step 29, current x [ 0.9 11.   0. ]
# pending candidatas...
# step 29, 18.41, next x, [ 0.9 15.   0. ]
# step 30, current x [ 0.9 15.   0. ]
# no candidates...
# step 30, 2.41, next x, [ 1. 15.  0.]
# step 31, current x [ 1. 15.  0.]
# pending candidatas...
# step 31, 2.5, next x, [ 0.9 17.   0. ]
# step 32, current x [ 0.9 17.   0. ]
# pending candidatas...
# step 32, 6.41, next x, [ 0.9 15.   2. ]
# step 33, current x [ 0.9 15.   2. ]
# pending candidatas...
# step 33, 0.41000000000000003, next x, [ 0. 15.  0.]
# step 34, current x [ 0. 15.  0.]
# pending candidatas...
# step 34, 2.5, next x, [ 0.9 13.   0. ]
# step 35, current x [ 0.9 13.   0. ]
# pending candidatas...
# step 35, 6.41, next x, [ 0.9 15.   0. ]
# step 36, current x [ 0.9 15.   0. ]
# no candidates...
# step 36, 2.41, next x, [ 1. 15.  2.]
# step 37, current x [ 1. 15.  2.]
# pending candidatas...
# step 37, 0.5, next x, [ 0.9 19.   2. ]
# step 38, current x [ 0.9 19.   2. ]
# pending candidatas...
# step 38, 16.41, next x, [ 0.9 15.   3. ]
# step 39, current x [ 0.9 15.   3. ]
# pending candidatas...
# step 39, 2.41, next x, [ 0. 15.  2.]
# step 40, current x [ 0. 15.  2.]
# pending candidatas...
# step 40, 0.5, next x, [ 0.9 11.   2. ]
# step 41, current x [ 0.9 11.   2. ]
# pending candidatas...
# step 41, 16.41, next x, [ 0.9 15.   0. ]
# step 42, current x [ 0.9 15.   0. ]
# no candidates...
# step 42, 2.41, next x, [ 1. 15.  2.]
# step 43, current x [ 1. 15.  2.]
# pending candidatas...
# step 43, 0.5, next x, [ 0.9 17.   2. ]
# step 44, current x [ 0.9 17.   2. ]
# pending candidatas...
# step 44, 4.41, next x, [ 0.9 15.   3. ]
# step 45, current x [ 0.9 15.   3. ]
# pending candidatas...
# step 45, 2.41, next x, [ 0. 15.  2.]
# step 46, current x [ 0. 15.  2.]
# pending candidatas...
# step 46, 0.5, next x, [ 0.9 13.   2. ]
# step 47, current x [ 0.9 13.   2. ]
# pending candidatas...
# step 47, 4.41, next x, [ 0.9 15.   0. ]
# step 48, current x [ 0.9 15.   0. ]
# no candidates...
# step 48, 2.41, next x, [ 1. 15.  2.]
# step 49, current x [ 1. 15.  2.]
# pending candidatas...
# step 49, 0.5, next x, [ 0.9 16.   2. ]
# step 50, current x [ 0.9 16.   2. ]
# pending candidatas...
# step 50, 1.4100000000000001, next x, [ 0.9 15.   3. ]
# step 51, current x [ 0.9 15.   3. ]
# pending candidatas...
# step 51, 2.41, next x, [ 0. 15.  2.]
# step 52, current x [ 0. 15.  2.]
# pending candidatas...
# step 52, 0.5, next x, [ 0.9 14.   2. ]
# step 53, current x [ 0.9 14.   2. ]
# pending candidatas...
# step 53, 1.4100000000000001, next x, [ 0.9 15.   1. ]
# step 54, current x [ 0.9 15.   1. ]
# no candidates...
# step 54, 0.41000000000000003, next x, [ 1. 15.  2.]
# step 55, current x [ 1. 15.  2.]
# pending candidatas...
# step 55, 0.5, next x, [ 0.9 15.5  2. ]
# step 56, current x [ 0.9 15.5  2. ]
# pending candidatas...
# step 56, 0.66, next x, [ 0.9 15.   2.5]
# step 57, current x [ 0.9 15.   2.5]
# pending candidatas...
# step 57, 1.1600000000000001, next x, [ 0.4 15.   2. ]
# step 58, current x [ 0.4 15.   2. ]
# pending candidatas...
# step 58, 0.26, next x, [ 0.9 14.5  2. ]
# step 59, current x [ 0.9 14.5  2. ]
# pending candidatas...
# step 59, 0.66, next x, [ 0.9 15.   1.5]
# step 60, current x [ 0.9 15.   1.5]
# no candidates...
# step 60, 0.16000000000000003, next x, [ 1.  15.   1.5]
# step 61, current x [ 1.  15.   1.5]
# pending candidatas...
# step 61, 0.25, next x, [ 0.9 16.   1.5]
# step 62, current x [ 0.9 16.   1.5]
# pending candidatas...
# step 62, 1.1600000000000001, next x, [ 0.9 15.   2.5]
# step 63, current x [ 0.9 15.   2.5]
# pending candidatas...
# step 63, 1.1600000000000001, next x, [ 0.  15.   1.5]
# step 64, current x [ 0.  15.   1.5]
# pending candidatas...
# step 64, 0.25, next x, [ 0.9 14.   1.5]
# step 65, current x [ 0.9 14.   1.5]
# pending candidatas...
# step 65, 1.1600000000000001, next x, [ 0.9 15.   0.5]
# step 66, current x [ 0.9 15.   0.5]
# no candidates...
# step 66, 1.1600000000000001, next x, [ 1.  15.   1.5]
# step 67, current x [ 1.  15.   1.5]
# pending candidatas...
# step 67, 0.25, next x, [ 0.9 15.5  1.5]
# step 68, current x [ 0.9 15.5  1.5]
# pending candidatas...
# step 68, 0.41000000000000003, next x, [ 0.9 15.   2. ]
# step 69, current x [ 0.9 15.   2. ]
# pending candidatas...
# step 69, 0.41000000000000003, next x, [ 0.4 15.   1.5]
# step 70, current x [ 0.4 15.   1.5]
# pending candidatas...
# step 70, 0.009999999999999995, next x, [ 0.9 14.5  1.5]
# step 71, current x [ 0.9 14.5  1.5]
# pending candidatas...
# step 71, 0.41000000000000003, next x, [ 0.9 15.   1. ]
# step 72, current x [ 0.9 15.   1. ]
# no candidates...
# step 72, 0.41000000000000003, next x, [ 1.  15.   1.5]
# step 73, current x [ 1.  15.   1.5]
# pending candidatas...
# step 73, 0.25, next x, [ 0.4 16.   1.5]
# step 74, current x [ 0.4 16.   1.5]
# pending candidatas...
# step 74, 1.01, next x, [ 0.4 15.   2.5]
# step 75, current x [ 0.4 15.   2.5]
# pending candidatas...
# step 75, 1.01, next x, [ 0.  15.   1.5]
# step 76, current x [ 0.  15.   1.5]
# pending candidatas...
# step 76, 0.25, next x, [ 0.4 14.   1.5]
# step 77, current x [ 0.4 14.   1.5]
# pending candidatas...
# step 77, 1.01, next x, [ 0.4 15.   0.5]
# step 78, current x [ 0.4 15.   0.5]
# no candidates...
# step 78, 1.01, next x, [ 0.9 15.   1.5]
# step 79, current x [ 0.9 15.   1.5]
# pending candidatas...
# step 79, 0.16000000000000003, next x, [ 0.4 15.5  1.5]
# step 80, current x [ 0.4 15.5  1.5]
# pending candidatas...
# step 80, 0.26, next x, [ 0.4 15.   2. ]
# step 81, current x [ 0.4 15.   2. ]
# pending candidatas...
# step 81, 0.26, next x, [ 0.  15.   1.5]
# step 82, current x [ 0.  15.   1.5]
# pending candidatas...
# step 82, 0.25, next x, [ 0.4 14.5  1.5]
# step 83, current x [ 0.4 14.5  1.5]
# pending candidatas...
# step 83, 0.26, next x, [ 0.4 15.   1. ]
# step 84, current x [ 0.4 15.   1. ]
# no candidates...
# step 84, 0.26, next x, [ 0.65 15.    1.5 ]
# step 85, current x [ 0.65 15.    1.5 ]
# pending candidatas...
# step 85, 0.022500000000000006, next x, [ 0.4  15.25  1.5 ]
# step 86, current x [ 0.4  15.25  1.5 ]
# pending candidatas...
# step 86, 0.0725, next x, [ 0.4  15.    1.75]
# step 87, current x [ 0.4  15.    1.75]
# pending candidatas...
# step 87, 0.0725, next x, [ 0.15 15.    1.5 ]
# step 88, current x [ 0.15 15.    1.5 ]
# pending candidatas...
# step 88, 0.12249999999999998, next x, [ 0.4  14.75  1.5 ]
# step 89, current x [ 0.4  14.75  1.5 ]
# pending candidatas...
# step 89, 0.0725, next x, [ 0.4  15.    1.25]
# step 90, current x [ 0.4  15.    1.25]
# no candidates...
# step 90, 0.0725, next x, [ 0.525 15.     1.5  ]
# step 91, current x [ 0.525 15.     1.5  ]
# pending candidatas...
# step 91, 0.0006250000000000011, next x, [ 0.4   15.125  1.5  ]
# step 92, current x [ 0.4   15.125  1.5  ]
# pending candidatas...
# step 92, 0.025624999999999995, next x, [ 0.4   15.     1.625]
# step 93, current x [ 0.4   15.     1.625]
# pending candidatas...
# step 93, 0.025624999999999995, next x, [ 0.275 15.     1.5  ]
# step 94, current x [ 0.275 15.     1.5  ]
# pending candidatas...
# step 94, 0.05062499999999999, next x, [ 0.4   14.875  1.5  ]
# step 95, current x [ 0.4   14.875  1.5  ]
# pending candidatas...
# step 95, 0.025624999999999995, next x, [ 0.4   15.     1.375]
# step 96, current x [ 0.4   15.     1.375]
# no candidates...
# step 96, 0.025624999999999995, next x, [ 0.775 15.     1.5  ]
# step 97, current x [ 0.775 15.     1.5  ]
# pending candidatas...
# step 97, 0.07562500000000001, next x, [ 0.525 15.25   1.5  ]
# step 98, current x [ 0.525 15.25   1.5  ]
# pending candidatas...
# step 98, 0.063125, next x, [ 0.525 15.     1.75 ]
# step 99, current x [ 0.525 15.     1.75 ]
# pending candidatas...
# step 99, 0.063125, next x, [ 0.275 15.     1.5  ]
# step 100, current x [ 0.275 15.     1.5  ]
# pending candidatas...
# step 100, 0.05062499999999999, next x, [ 0.525 14.75   1.5  ]
# step 101, current x [ 0.525 14.75   1.5  ]
# pending candidatas...
# step 101, 0.063125, next x, [ 0.525 15.     1.25 ]
# step 102, current x [ 0.525 15.     1.25 ]
# no candidates...
# step 102, 0.063125, next x, [ 0.65 15.    1.5 ]
# step 103, current x [ 0.65 15.    1.5 ]
# pending candidatas...
# step 103, 0.022500000000000006, next x, [ 0.525 15.125  1.5  ]
# step 104, current x [ 0.525 15.125  1.5  ]
# pending candidatas...
# step 104, 0.01625, next x, [ 0.525 15.     1.625]
# step 105, current x [ 0.525 15.     1.625]
# pending candidatas...
# step 105, 0.01625, next x, [ 0.4 15.   1.5]
# step 106, current x [ 0.4 15.   1.5]
# pending candidatas...
# step 106, 0.009999999999999995, next x, [ 0.525 14.875  1.5  ]
# step 107, current x [ 0.525 14.875  1.5  ]
# pending candidatas...
# step 107, 0.01625, next x, [ 0.525 15.     1.375]
# step 108, current x [ 0.525 15.     1.375]
# no candidates...
# step 108, 0.01625, next x, [ 0.5875 15.      1.5   ]
# step 109, current x [ 0.5875 15.      1.5   ]
# pending candidatas...
# step 109, 0.007656250000000004, next x, [ 0.525  15.0625  1.5   ]
# step 110, current x [ 0.525  15.0625  1.5   ]
# pending candidatas...
# step 110, 0.004531250000000001, next x, [ 0.525  15.      1.5625]
# step 111, current x [ 0.525  15.      1.5625]
# pending candidatas...
# step 111, 0.004531250000000001, next x, [ 0.4625 15.      1.5   ]
# step 112, current x [ 0.4625 15.      1.5   ]
# pending candidatas...
# step 112, 0.0014062499999999984, next x, [ 0.525  14.9375  1.5   ]
# step 113, current x [ 0.525  14.9375  1.5   ]
# pending candidatas...
# step 113, 0.004531250000000001, next x, [ 0.525  15.      1.4375]
# step 114, current x [ 0.525  15.      1.4375]
# no candidates...
# step 114, 0.004531250000000001, next x, [ 0.55625 15.       1.5    ]
# step 115, current x [ 0.55625 15.       1.5    ]
# pending candidatas...
# step 115, 0.0031640625000000024, next x, [ 0.525   15.03125  1.5    ]
# step 116, current x [ 0.525   15.03125  1.5    ]
# pending candidatas...
# step 116, 0.001601562500000001, next x, [ 0.525   15.       1.53125]
# step 117, current x [ 0.525   15.       1.53125]
# pending candidatas...
# step 117, 0.001601562500000001, next x, [ 0.49375 15.       1.5    ]
# step 118, current x [ 0.49375 15.       1.5    ]
# pending candidatas...
# step 118, 3.906249999999972e-05, next x, [ 0.525   14.96875  1.5    ]
# step 119, current x [ 0.525   14.96875  1.5    ]
# pending candidatas...
# step 119, 0.001601562500000001, next x, [ 0.525   15.       1.46875]
