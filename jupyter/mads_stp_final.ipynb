# %% [markdown]
# ## Org MADS

# %%
import numpy as np

def objective(x):
    a, b, c = x
    return (a - 0.5)**2 + (b - 15)**2 + (c - 1.5)**2  # Example function

# Bounds for each variable
bounds = np.array([[0, 1], [10, 20], [0, 3]])

# Initial guess
x0 = np.array([0.9, 19, 0.1])

def mads(func, x0, bounds, delta=1.0, tol=1e-6, max_iter=100):
    """ Mesh Adaptive Direct Search (MADS) implementation. """
    n = len(x0)
    x = x0.copy()
    delta_min = tol
    iteration = 0
    
    while delta > delta_min and iteration < max_iter:
        improved = False
        
        # Generate trial points
        for i in range(n):
            for direction in [-1, 1]:
                x_new = x.copy()
                x_new[i] += direction * delta
                x_new = np.clip(x_new, bounds[:, 0], bounds[:, 1])  # Enforce bounds
                
                if func(x_new) < func(x):
                    x = x_new
                    improved = True
        
        # Reduce mesh size if no improvement
        if not improved:
            delta /= 2.0
        
        iteration += 1
        yield x, func(x), iteration

# Run MADS optimization
mads_iter = mads(objective, x0, bounds)
for x, fval, step in mads_iter:
    print(f"Step {step}: x = {x}, f(x) = {fval}")
# Out:
# Step 1: x = [ 0.9 18.   1.1], f(x) = 9.32
# Step 2: x = [ 0.9 17.   1.1], f(x) = 4.32
# Step 3: x = [ 0.9 16.   1.1], f(x) = 1.32
# Step 4: x = [ 0.9 15.   1.1], f(x) = 0.31999999999999995
# Step 5: x = [ 0.9 15.   1.1], f(x) = 0.31999999999999995
# Step 6: x = [ 0.4 15.   1.6], f(x) = 0.02000000000000001
# Step 7: x = [ 0.4 15.   1.6], f(x) = 0.02000000000000001
# Step 8: x = [ 0.4 15.   1.6], f(x) = 0.02000000000000001
# Step 9: x = [ 0.525 15.     1.475], f(x) = 0.0012499999999999968
# Step 10: x = [ 0.525 15.     1.475], f(x) = 0.0012499999999999968
# Step 11: x = [ 0.525 15.     1.475], f(x) = 0.0012499999999999968
# Step 12: x = [ 0.49375 15.       1.50625], f(x) = 7.812500000000083e-05
# Step 13: x = [ 0.49375 15.       1.50625], f(x) = 7.812500000000083e-05
# Step 14: x = [ 0.49375 15.       1.50625], f(x) = 7.812500000000083e-05
# Step 15: x = [ 0.5015625 15.         1.4984375], f(x) = 4.882812499999793e-06
# Step 16: x = [ 0.5015625 15.         1.4984375], f(x) = 4.882812499999793e-06
# Step 17: x = [ 0.5015625 15.         1.4984375], f(x) = 4.882812499999793e-06
# Step 18: x = [ 0.49960938 15.          1.50039063], f(x) = 3.0517578125005205e-07
# Step 19: x = [ 0.49960938 15.          1.50039063], f(x) = 3.0517578125005205e-07
# Step 20: x = [ 0.49960938 15.          1.50039063], f(x) = 3.0517578125005205e-07
# Step 21: x = [ 0.50009766 15.          1.49990234], f(x) = 1.9073486328111987e-08
# Step 22: x = [ 0.50009766 15.          1.49990234], f(x) = 1.9073486328111987e-08
# Step 23: x = [ 0.50009766 15.          1.49990234], f(x) = 1.9073486328111987e-08
# Step 24: x = [ 0.49997559 15.          1.50002441], f(x) = 1.1920928955110652e-09
# Step 25: x = [ 0.49997559 15.          1.50002441], f(x) = 1.1920928955110652e-09
# Step 26: x = [ 0.49997559 15.          1.50002441], f(x) = 1.1920928955110652e-09
# Step 27: x = [ 0.5000061 15.         1.4999939], f(x) = 7.450580596842513e-11
# Step 28: x = [ 0.5000061 15.         1.4999939], f(x) = 7.450580596842513e-11
# Step 29: x = [ 0.5000061 15.         1.4999939], f(x) = 7.450580596842513e-11
# Step 30: x = [ 0.49999847 15.          1.50000153], f(x) = 4.656612873280681e-12
# Step 31: x = [ 0.49999847 15.          1.50000153], f(x) = 4.656612873280681e-12
# Step 32: x = [ 0.49999847 15.          1.50000153], f(x) = 4.656612873280681e-12
# Step 33: x = [ 0.50000038 15.          1.49999962], f(x) = 2.9103830451651506e-13
# Step 34: x = [ 0.50000038 15.          1.49999962], f(x) = 2.9103830451651506e-13

# %% [markdown]
# ### Stepwise MADS, on iterations

# %%
import numpy as np

class StepwiseMADS:
    def __init__(self, x0, bounds, delta0=1.0, delta_min=1e-3, alpha=2.0, gamma=0.5):
        self.x = np.array(x0)
        self.bounds = np.array(bounds)
        self.delta = delta0
        self.delta_min = delta_min
        self.alpha = alpha
        self.gamma = gamma
        self.mesh_size = delta0
        self.iteration = 0
        self.pending_eval = None
        self.best_value = None  # Store the best evaluation value
    
    def get_next_candidate(self):
        if self.pending_eval is not None:
            raise RuntimeError("Previous evaluation result is still pending.")
        
        directions = np.eye(len(self.x))
        candidates = [self.x + self.mesh_size * d for d in directions] + [self.x - self.mesh_size * d for d in directions]
        
        candidates = [np.clip(c, self.bounds[:, 0], self.bounds[:, 1]) for c in candidates]
        self.pending_eval = candidates.copy()
        return candidates
    
    def update_with_result(self, evaluations):
        if self.pending_eval is None:
            raise RuntimeError("No pending evaluations to update with.")
        
        best_idx = np.argmin(evaluations)
        best_candidate = self.pending_eval[best_idx]
        best_value = evaluations[best_idx]
        
        if self.best_value is None or best_value < self.best_value:
            self.x = best_candidate
            self.best_value = best_value
            self.mesh_size *= self.alpha
        else:
            self.mesh_size *= self.gamma
        
        self.mesh_size = max(self.mesh_size, self.delta_min)
        self.pending_eval = None
        self.iteration += 1
    
    def get_current_solution(self):
        return self.x

# %%
# Example Usage
def obj_func(x):
    a, b, c = x
    return (a - 0.5)**2 + (b - 15)**2 + (c - 1.5)**2  # Example function

bounds = np.array([[0, 1], [10, 20], [0, 3]])
mads = StepwiseMADS(x0=[0.9, 19, 0.1], bounds=bounds)

# %%
mads.pending_eval

# %%
# Example Usage
def obj_func(x):
    a, b, c = x
    return (a - 0.5)**2 + (b - 15)**2 + (c - 1.5)**2  # Example function

bounds = np.array([[0, 1], [10, 20], [0, 3]])
mads = StepwiseMADS(x0=[0.9, 19, 0.1], bounds=bounds)
mads.best_value = obj_func(mads.x)  # Initialize best value with initial point evaluation
print("initial best value", mads.best_value)

for _ in range(20):  # Run for a few iterations
    candidates = mads.get_next_candidate()
    # print(mads.pending_eval)
    evaluations = [float(obj_func(c)) for c in candidates]  # Simulated evaluation
    mads.update_with_result(evaluations)
    # print(f"Iter {_}candidates, evaluations", list(zip(candidates, evaluations)))
    print(f"Iteration {_}: Best solution {mads.get_current_solution()} with value {mads.best_value}")
# Out:
# initial best value 18.12
# Iteration 0: Best solution [ 0.9 18.   0.1] with value 11.12
# Iteration 1: Best solution [ 0.9 16.   0.1] with value 3.12
# Iteration 2: Best solution [ 0.9 16.   0.1] with value 3.12
# Iteration 3: Best solution [ 0.9 16.   2.1] with value 1.5200000000000002
# Iteration 4: Best solution [ 0.9 16.   2.1] with value 1.5200000000000002
# Iteration 5: Best solution [ 0.9 16.   2.1] with value 1.5200000000000002
# Iteration 6: Best solution [ 0.9 15.   2.1] with value 0.5200000000000001
# Iteration 7: Best solution [ 0.9 15.   2.1] with value 0.5200000000000001
# Iteration 8: Best solution [ 0.9 15.   1.1] with value 0.31999999999999995
# Iteration 9: Best solution [ 0.9 15.   1.1] with value 0.31999999999999995
# Iteration 10: Best solution [ 0.9 15.   1.1] with value 0.31999999999999995
# Iteration 11: Best solution [ 0.4 15.   1.1] with value 0.16999999999999993
# Iteration 12: Best solution [ 0.4 15.   1.1] with value 0.16999999999999993
# Iteration 13: Best solution [ 0.4 15.   1.6] with value 0.02000000000000001
# Iteration 14: Best solution [ 0.4 15.   1.6] with value 0.02000000000000001
# Iteration 15: Best solution [ 0.4 15.   1.6] with value 0.02000000000000001
# Iteration 16: Best solution [ 0.4 15.   1.6] with value 0.02000000000000001
# Iteration 17: Best solution [ 0.4   15.     1.475] with value 0.01062499999999999
# Iteration 18: Best solution [ 0.4   15.     1.475] with value 0.01062499999999999
# Iteration 19: Best solution [ 0.525 15.     1.475] with value 0.0012499999999999968

# %% [markdown]
# ## Stp on every call

# %%
import math

class MADS:
    def __init__(self, x0, initial_value, bounds, delta0=1.0, delta_min=1e-3, alpha=2.0, gamma=0.5):
        self.stp_MADS = StepwiseMADS(x0, bounds=bounds, delta0=delta0, delta_min=delta_min, alpha=alpha, gamma=gamma)
        self.candidates = []
        self.evaluations = []
        self.step_num = 0
        self.stp_MADS.best_value = initial_value

    def step(self, evaluation):
        self.evaluations.append(evaluation)
        if self.candidates == []:
            # new MADS iteration
            print("no candidates...")
            
            self.candidates = self.stp_MADS.get_next_candidate()
            self.stp_MADS.update_with_result(self.evaluations)
            self.evaluations = []
        else:
            print("pending candidatas...")
        return self.candidates.pop(0)

# %%
x0=[0.9, 19, 0.1]
initial_value = obj_func(x0)
bounds = np.array([[0, 1], [10, 20], [0, 3]])
ab = MADS(x0, initial_value, bounds)

# %%
x = ab.step(initial_value)
# Out:
# no candidates...

# %%
x
# Out:
# array([ 1. , 19. ,  0.1])

# %%
for _ in range(200): 
    print(f"current x {x}")
    evaluation = obj_func(x)
    x = ab.step(evaluation)
    print(f"step {_}, {evaluation}, next x, {x}")
# Out:
# current x [ 0.9 18.5  0.6]
# pending candidatas...
# step 0, 13.22, next x, [ 0.4 18.5  0.1]
# current x [ 0.4 18.5  0.1]
# pending candidatas...
# step 1, 14.219999999999999, next x, [ 0.9 18.   0.1]
# current x [ 0.9 18.   0.1]
# pending candidatas...
# step 2, 11.12, next x, [ 0.9 18.5  0. ]
# current x [ 0.9 18.5  0. ]
# no candidates...
# step 3, 14.66, next x, [ 1.  18.   0.1]
# current x [ 1.  18.   0.1]
# pending candidatas...
# step 4, 11.209999999999999, next x, [ 0.9 19.   0.1]
# current x [ 0.9 19.   0.1]
# pending candidatas...
# step 5, 18.12, next x, [ 0.9 18.   1.1]
# current x [ 0.9 18.   1.1]
# pending candidatas...
# step 6, 9.32, next x, [ 0.  18.   0.1]
# current x [ 0.  18.   0.1]
# pending candidatas...
# step 7, 11.209999999999999, next x, [ 0.9 17.   0.1]
# current x [ 0.9 17.   0.1]
# pending candidatas...
# step 8, 6.12, next x, [ 0.9 18.   0. ]
# current x [ 0.9 18.   0. ]
# no candidates...
# step 9, 11.41, next x, [ 1.  18.   0.1]
# current x [ 1.  18.   0.1]
# pending candidatas...
# step 10, 11.209999999999999, next x, [ 0.9 18.5  0.1]
# current x [ 0.9 18.5  0.1]
# pending candidatas...
# step 11, 14.37, next x, [ 0.9 18.   0.6]
# current x [ 0.9 18.   0.6]
# pending candidatas...
# step 12, 9.97, next x, [ 0.4 18.   0.1]
# current x [ 0.4 18.   0.1]
# pending candidatas...
# step 13, 10.969999999999999, next x, [ 0.9 17.5  0.1]
# current x [ 0.9 17.5  0.1]
# pending candidatas...
# step 14, 8.37, next x, [ 0.9 18.   0. ]
# current x [ 0.9 18.   0. ]
# no candidates...
# step 15, 11.41, next x, [ 1.  17.5  0.1]
# current x [ 1.  17.5  0.1]
# pending candidatas...
# step 16, 8.459999999999999, next x, [ 0.9 18.5  0.1]
# current x [ 0.9 18.5  0.1]
# pending candidatas...
# step 17, 14.37, next x, [ 0.9 17.5  1.1]
# current x [ 0.9 17.5  1.1]
# pending candidatas...
# step 18, 6.57, next x, [ 0.  17.5  0.1]
# current x [ 0.  17.5  0.1]
# pending candidatas...
# step 19, 8.459999999999999, next x, [ 0.9 16.5  0.1]
# current x [ 0.9 16.5  0.1]
# pending candidatas...
# step 20, 4.37, next x, [ 0.9 17.5  0. ]
# current x [ 0.9 17.5  0. ]
# no candidates...
# step 21, 8.66, next x, [ 1.  17.5  0.1]
# current x [ 1.  17.5  0.1]
# pending candidatas...
# step 22, 8.459999999999999, next x, [ 0.9 18.   0.1]
# current x [ 0.9 18.   0.1]
# pending candidatas...
# step 23, 11.12, next x, [ 0.9 17.5  0.6]
# current x [ 0.9 17.5  0.6]
# pending candidatas...
# step 24, 7.220000000000001, next x, [ 0.4 17.5  0.1]
# current x [ 0.4 17.5  0.1]
# pending candidatas...
# step 25, 8.219999999999999, next x, [ 0.9 17.   0.1]
# current x [ 0.9 17.   0.1]
# pending candidatas...
# step 26, 6.12, next x, [ 0.9 17.5  0. ]
# current x [ 0.9 17.5  0. ]
# no candidates...
# step 27, 8.66, next x, [ 1.  17.   0.1]
# current x [ 1.  17.   0.1]
# pending candidatas...
# step 28, 6.21, next x, [ 0.9 18.   0.1]
# current x [ 0.9 18.   0.1]
# pending candidatas...
# step 29, 11.12, next x, [ 0.9 17.   1.1]
# current x [ 0.9 17.   1.1]
# pending candidatas...
# step 30, 4.32, next x, [ 0.  17.   0.1]
# current x [ 0.  17.   0.1]
# pending candidatas...
# step 31, 6.21, next x, [ 0.9 16.   0.1]
# current x [ 0.9 16.   0.1]
# pending candidatas...
# step 32, 3.12, next x, [ 0.9 17.   0. ]
# current x [ 0.9 17.   0. ]
# no candidates...
# step 33, 6.41, next x, [ 1.  17.   0.1]
# current x [ 1.  17.   0.1]
# pending candidatas...
# step 34, 6.21, next x, [ 0.9 17.5  0.1]
# current x [ 0.9 17.5  0.1]
# pending candidatas...
# step 35, 8.37, next x, [ 0.9 17.   0.6]
# current x [ 0.9 17.   0.6]
# pending candidatas...
# step 36, 4.970000000000001, next x, [ 0.4 17.   0.1]
# current x [ 0.4 17.   0.1]
# pending candidatas...
# step 37, 5.97, next x, [ 0.9 16.5  0.1]
# current x [ 0.9 16.5  0.1]
# pending candidatas...
# step 38, 4.37, next x, [ 0.9 17.   0. ]
# current x [ 0.9 17.   0. ]
# no candidates...
# step 39, 6.41, next x, [ 1.  16.5  0.1]
# current x [ 1.  16.5  0.1]
# pending candidatas...
# step 40, 4.46, next x, [ 0.9 17.5  0.1]
# current x [ 0.9 17.5  0.1]
# pending candidatas...
# step 41, 8.37, next x, [ 0.9 16.5  1.1]
# current x [ 0.9 16.5  1.1]
# pending candidatas...
# step 42, 2.5700000000000003, next x, [ 0.  16.5  0.1]
# current x [ 0.  16.5  0.1]
# pending candidatas...
# step 43, 4.46, next x, [ 0.9 15.5  0.1]
# current x [ 0.9 15.5  0.1]
# pending candidatas...
# step 44, 2.3699999999999997, next x, [ 0.9 16.5  0. ]
# current x [ 0.9 16.5  0. ]
# no candidates...
# step 45, 4.66, next x, [ 1.  16.5  0.1]
# current x [ 1.  16.5  0.1]
# pending candidatas...
# step 46, 4.46, next x, [ 0.9 17.   0.1]
# current x [ 0.9 17.   0.1]
# pending candidatas...
# step 47, 6.12, next x, [ 0.9 16.5  0.6]
# current x [ 0.9 16.5  0.6]
# pending candidatas...
# step 48, 3.22, next x, [ 0.4 16.5  0.1]
# current x [ 0.4 16.5  0.1]
# pending candidatas...
# step 49, 4.22, next x, [ 0.9 16.   0.1]
# current x [ 0.9 16.   0.1]
# pending candidatas...
# step 50, 3.12, next x, [ 0.9 16.5  0. ]
# current x [ 0.9 16.5  0. ]
# no candidates...
# step 51, 4.66, next x, [ 1.  16.   0.1]
# current x [ 1.  16.   0.1]
# pending candidatas...
# step 52, 3.21, next x, [ 0.9 17.   0.1]
# current x [ 0.9 17.   0.1]
# pending candidatas...
# step 53, 6.12, next x, [ 0.9 16.   1.1]
# current x [ 0.9 16.   1.1]
# pending candidatas...
# step 54, 1.32, next x, [ 0.  16.   0.1]
# current x [ 0.  16.   0.1]
# pending candidatas...
# step 55, 3.21, next x, [ 0.9 15.   0.1]
# current x [ 0.9 15.   0.1]
# pending candidatas...
# step 56, 2.1199999999999997, next x, [ 0.9 16.   0. ]
# current x [ 0.9 16.   0. ]
# no candidates...
# step 57, 3.41, next x, [ 1.  16.   0.1]
# current x [ 1.  16.   0.1]
# pending candidatas...
# step 58, 3.21, next x, [ 0.9 16.5  0.1]
# current x [ 0.9 16.5  0.1]
# pending candidatas...
# step 59, 4.37, next x, [ 0.9 16.   0.6]
# current x [ 0.9 16.   0.6]
# pending candidatas...
# step 60, 1.9700000000000002, next x, [ 0.4 16.   0.1]
# current x [ 0.4 16.   0.1]
# pending candidatas...
# step 61, 2.9699999999999998, next x, [ 0.9 15.5  0.1]
# current x [ 0.9 15.5  0.1]
# pending candidatas...
# step 62, 2.3699999999999997, next x, [ 0.9 16.   0. ]
# current x [ 0.9 16.   0. ]
# no candidates...
# step 63, 3.41, next x, [ 1.  16.   0.6]
# current x [ 1.  16.   0.6]
# pending candidatas...
# step 64, 2.06, next x, [ 0.9 17.   0.6]
# current x [ 0.9 17.   0.6]
# pending candidatas...
# step 65, 4.970000000000001, next x, [ 0.9 16.   1.6]
# current x [ 0.9 16.   1.6]
# pending candidatas...
# step 66, 1.1700000000000002, next x, [ 0.  16.   0.6]
# current x [ 0.  16.   0.6]
# pending candidatas...
# step 67, 2.06, next x, [ 0.9 15.   0.6]
# current x [ 0.9 15.   0.6]
# pending candidatas...
# step 68, 0.9700000000000001, next x, [ 0.9 16.   0. ]
# current x [ 0.9 16.   0. ]
# no candidates...
# step 69, 3.41, next x, [ 1.  16.   0.6]
# current x [ 1.  16.   0.6]
# pending candidatas...
# step 70, 2.06, next x, [ 0.9 16.5  0.6]
# current x [ 0.9 16.5  0.6]
# pending candidatas...
# step 71, 3.22, next x, [ 0.9 16.   1.1]
# current x [ 0.9 16.   1.1]
# pending candidatas...
# step 72, 1.32, next x, [ 0.4 16.   0.6]
# current x [ 0.4 16.   0.6]
# pending candidatas...
# step 73, 1.82, next x, [ 0.9 15.5  0.6]
# current x [ 0.9 15.5  0.6]
# pending candidatas...
# step 74, 1.2200000000000002, next x, [ 0.9 16.   0.1]
# current x [ 0.9 16.   0.1]
# no candidates...
# step 75, 3.12, next x, [ 1.  15.5  0.6]
# current x [ 1.  15.5  0.6]
# pending candidatas...
# step 76, 1.31, next x, [ 0.9 16.5  0.6]
# current x [ 0.9 16.5  0.6]
# pending candidatas...
# step 77, 3.22, next x, [ 0.9 15.5  1.6]
# current x [ 0.9 15.5  1.6]
# pending candidatas...
# step 78, 0.42000000000000004, next x, [ 0.  15.5  0.6]
# current x [ 0.  15.5  0.6]
# pending candidatas...
# step 79, 1.31, next x, [ 0.9 14.5  0.6]
# current x [ 0.9 14.5  0.6]
# pending candidatas...
# step 80, 1.2200000000000002, next x, [ 0.9 15.5  0. ]
# current x [ 0.9 15.5  0. ]
# no candidates...
# step 81, 2.66, next x, [ 1.  15.5  0.6]
# current x [ 1.  15.5  0.6]
# pending candidatas...
# step 82, 1.31, next x, [ 0.9 16.   0.6]
# current x [ 0.9 16.   0.6]
# pending candidatas...
# step 83, 1.9700000000000002, next x, [ 0.9 15.5  1.1]
# current x [ 0.9 15.5  1.1]
# pending candidatas...
# step 84, 0.57, next x, [ 0.4 15.5  0.6]
# current x [ 0.4 15.5  0.6]
# pending candidatas...
# step 85, 1.07, next x, [ 0.9 15.   0.6]
# current x [ 0.9 15.   0.6]
# pending candidatas...
# step 86, 0.9700000000000001, next x, [ 0.9 15.5  0.1]
# current x [ 0.9 15.5  0.1]
# no candidates...
# step 87, 2.3699999999999997, next x, [ 1.  15.5  1.1]
# current x [ 1.  15.5  1.1]
# pending candidatas...
# step 88, 0.6599999999999999, next x, [ 0.9 16.5  1.1]
# current x [ 0.9 16.5  1.1]
# pending candidatas...
# step 89, 2.5700000000000003, next x, [ 0.9 15.5  2.1]
# current x [ 0.9 15.5  2.1]
# pending candidatas...
# step 90, 0.7700000000000001, next x, [ 0.  15.5  1.1]
# current x [ 0.  15.5  1.1]
# pending candidatas...
# step 91, 0.6599999999999999, next x, [ 0.9 14.5  1.1]
# current x [ 0.9 14.5  1.1]
# pending candidatas...
# step 92, 0.57, next x, [ 0.9 15.5  0.1]
# current x [ 0.9 15.5  0.1]
# no candidates...
# step 93, 2.3699999999999997, next x, [ 1.  15.5  1.1]
# current x [ 1.  15.5  1.1]
# pending candidatas...
# step 94, 0.6599999999999999, next x, [ 0.9 16.   1.1]
# current x [ 0.9 16.   1.1]
# pending candidatas...
# step 95, 1.32, next x, [ 0.9 15.5  1.6]
# current x [ 0.9 15.5  1.6]
# pending candidatas...
# step 96, 0.42000000000000004, next x, [ 0.4 15.5  1.1]
# current x [ 0.4 15.5  1.1]
# pending candidatas...
# step 97, 0.41999999999999993, next x, [ 0.9 15.   1.1]
# current x [ 0.9 15.   1.1]
# pending candidatas...
# step 98, 0.31999999999999995, next x, [ 0.9 15.5  0.6]
# current x [ 0.9 15.5  0.6]
# no candidates...
# step 99, 1.2199999999999998, next x, [ 1.  15.5  1.1]
# current x [ 1.  15.5  1.1]
# pending candidatas...
# step 100, 0.6599999999999999, next x, [ 0.9  15.75  1.1 ]
# current x [ 0.9  15.75  1.1 ]
# pending candidatas...
# step 101, 0.8825, next x, [ 0.9  15.5   1.35]
# current x [ 0.9  15.5   1.35]
# pending candidatas...
# step 102, 0.4325, next x, [ 0.65 15.5   1.1 ]
# current x [ 0.65 15.5   1.1 ]
# pending candidatas...
# step 103, 0.43249999999999994, next x, [ 0.9  15.25  1.1 ]
# current x [ 0.9  15.25  1.1 ]
# pending candidatas...
# step 104, 0.38249999999999995, next x, [ 0.9  15.5   0.85]
# current x [ 0.9  15.5   0.85]
# no candidates...
# step 105, 0.8324999999999999, next x, [ 1.   15.25  1.1 ]
# current x [ 1.   15.25  1.1 ]
# pending candidatas...
# step 106, 0.4724999999999999, next x, [ 0.9  15.75  1.1 ]
# current x [ 0.9  15.75  1.1 ]
# pending candidatas...
# step 107, 0.8825, next x, [ 0.9  15.25  1.6 ]
# current x [ 0.9  15.25  1.6 ]
# pending candidatas...
# step 108, 0.23250000000000004, next x, [ 0.4  15.25  1.1 ]
# current x [ 0.4  15.25  1.1 ]
# pending candidatas...
# step 109, 0.23249999999999993, next x, [ 0.9  14.75  1.1 ]
# current x [ 0.9  14.75  1.1 ]
# pending candidatas...
# step 110, 0.38249999999999995, next x, [ 0.9  15.25  0.6 ]
# current x [ 0.9  15.25  0.6 ]
# no candidates...
# step 111, 1.0324999999999998, next x, [ 1.   15.25  1.1 ]
# current x [ 1.   15.25  1.1 ]
# pending candidatas...
# step 112, 0.4724999999999999, next x, [ 0.9 15.5  1.1]
# current x [ 0.9 15.5  1.1]
# pending candidatas...
# step 113, 0.57, next x, [ 0.9  15.25  1.35]
# current x [ 0.9  15.25  1.35]
# pending candidatas...
# step 114, 0.245, next x, [ 0.65 15.25  1.1 ]
# current x [ 0.65 15.25  1.1 ]
# pending candidatas...
# step 115, 0.24499999999999994, next x, [ 0.9 15.   1.1]
# current x [ 0.9 15.   1.1]
# pending candidatas...
# step 116, 0.31999999999999995, next x, [ 0.9  15.25  0.85]
# current x [ 0.9  15.25  0.85]
# no candidates...
# step 117, 0.6449999999999999, next x, [ 1.   15.25  1.1 ]
# current x [ 1.   15.25  1.1 ]
# pending candidatas...
# step 118, 0.4724999999999999, next x, [ 0.65 15.75  1.1 ]
# current x [ 0.65 15.75  1.1 ]
# pending candidatas...
# step 119, 0.7449999999999999, next x, [ 0.65 15.25  1.6 ]
# current x [ 0.65 15.25  1.6 ]
# pending candidatas...
# step 120, 0.09500000000000003, next x, [ 0.15 15.25  1.1 ]
# current x [ 0.15 15.25  1.1 ]
# pending candidatas...
# step 121, 0.3449999999999999, next x, [ 0.65 14.75  1.1 ]
# current x [ 0.65 14.75  1.1 ]
# pending candidatas...
# step 122, 0.24499999999999994, next x, [ 0.65 15.25  0.6 ]
# current x [ 0.65 15.25  0.6 ]
# no candidates...
# step 123, 0.8949999999999998, next x, [ 0.9  15.25  1.1 ]
# current x [ 0.9  15.25  1.1 ]
# pending candidatas...
# step 124, 0.38249999999999995, next x, [ 0.65 15.5   1.1 ]
# current x [ 0.65 15.5   1.1 ]
# pending candidatas...
# step 125, 0.43249999999999994, next x, [ 0.65 15.25  1.35]
# current x [ 0.65 15.25  1.35]
# pending candidatas...
# step 126, 0.10749999999999998, next x, [ 0.4  15.25  1.1 ]
# current x [ 0.4  15.25  1.1 ]
# pending candidatas...
# step 127, 0.23249999999999993, next x, [ 0.65 15.    1.1 ]
# current x [ 0.65 15.    1.1 ]
# pending candidatas...
# step 128, 0.18249999999999994, next x, [ 0.65 15.25  0.85]
# current x [ 0.65 15.25  0.85]
# no candidates...
# step 129, 0.5074999999999998, next x, [ 1.   15.25  1.35]
# current x [ 1.   15.25  1.35]
# pending candidatas...
# step 130, 0.33499999999999996, next x, [ 0.65 15.75  1.35]
# current x [ 0.65 15.75  1.35]
# pending candidatas...
# step 131, 0.6074999999999999, next x, [ 0.65 15.25  1.85]
# current x [ 0.65 15.25  1.85]
# pending candidatas...
# step 132, 0.20750000000000007, next x, [ 0.15 15.25  1.35]
# current x [ 0.15 15.25  1.35]
# pending candidatas...
# step 133, 0.20749999999999996, next x, [ 0.65 14.75  1.35]
# current x [ 0.65 14.75  1.35]
# pending candidatas...
# step 134, 0.10749999999999998, next x, [ 0.65 15.25  0.85]
# current x [ 0.65 15.25  0.85]
# no candidates...
# step 135, 0.5074999999999998, next x, [ 0.9  15.25  1.35]
# current x [ 0.9  15.25  1.35]
# pending candidatas...
# step 136, 0.245, next x, [ 0.65 15.5   1.35]
# current x [ 0.65 15.5   1.35]
# pending candidatas...
# step 137, 0.295, next x, [ 0.65 15.25  1.6 ]
# current x [ 0.65 15.25  1.6 ]
# pending candidatas...
# step 138, 0.09500000000000003, next x, [ 0.4  15.25  1.35]
# current x [ 0.4  15.25  1.35]
# pending candidatas...
# step 139, 0.09499999999999997, next x, [ 0.65 15.    1.35]
# current x [ 0.65 15.    1.35]
# pending candidatas...
# step 140, 0.044999999999999984, next x, [ 0.65 15.25  1.1 ]
# current x [ 0.65 15.25  1.1 ]
# no candidates...
# step 141, 0.24499999999999994, next x, [ 0.775 15.25   1.35 ]
# current x [ 0.775 15.25   1.35 ]
# pending candidatas...
# step 142, 0.16062499999999996, next x, [ 0.65  15.375  1.35 ]
# current x [ 0.65  15.375  1.35 ]
# pending candidatas...
# step 143, 0.18562499999999998, next x, [ 0.65  15.25   1.475]
# current x [ 0.65  15.25   1.475]
# pending candidatas...
# step 144, 0.085625, next x, [ 0.525 15.25   1.35 ]
# current x [ 0.525 15.25   1.35 ]
# pending candidatas...
# step 145, 0.08562499999999998, next x, [ 0.65  15.125  1.35 ]
# current x [ 0.65  15.125  1.35 ]
# pending candidatas...
# step 146, 0.060624999999999984, next x, [ 0.65  15.25   1.225]
# current x [ 0.65  15.25   1.225]
# no candidates...
# step 147, 0.16062499999999996, next x, [ 0.9   15.125  1.35 ]
# current x [ 0.9   15.125  1.35 ]
# pending candidatas...
# step 148, 0.198125, next x, [ 0.65  15.375  1.35 ]
# current x [ 0.65  15.375  1.35 ]
# pending candidatas...
# step 149, 0.18562499999999998, next x, [ 0.65  15.125  1.6  ]
# current x [ 0.65  15.125  1.6  ]
# pending candidatas...
# step 150, 0.04812500000000002, next x, [ 0.4   15.125  1.35 ]
# current x [ 0.4   15.125  1.35 ]
# pending candidatas...
# step 151, 0.04812499999999997, next x, [ 0.65  14.875  1.35 ]
# current x [ 0.65  14.875  1.35 ]
# pending candidatas...
# step 152, 0.060624999999999984, next x, [ 0.65  15.125  1.1  ]
# current x [ 0.65  15.125  1.1  ]
# no candidates...
# step 153, 0.19812499999999994, next x, [ 0.775 15.125  1.35 ]
# current x [ 0.775 15.125  1.35 ]
# pending candidatas...
# step 154, 0.11374999999999999, next x, [ 0.65 15.25  1.35]
# current x [ 0.65 15.25  1.35]
# pending candidatas...
# step 155, 0.10749999999999998, next x, [ 0.65  15.125  1.475]
# current x [ 0.65  15.125  1.475]
# pending candidatas...
# step 156, 0.03875, next x, [ 0.525 15.125  1.35 ]
# current x [ 0.525 15.125  1.35 ]
# pending candidatas...
# step 157, 0.03874999999999998, next x, [ 0.65 15.    1.35]
# current x [ 0.65 15.    1.35]
# pending candidatas...
# step 158, 0.044999999999999984, next x, [ 0.65  15.125  1.225]
# current x [ 0.65  15.125  1.225]
# no candidates...
# step 159, 0.11374999999999996, next x, [ 0.7125 15.125   1.35  ]
# current x [ 0.7125 15.125   1.35  ]
# pending candidatas...
# step 160, 0.08328124999999999, next x, [ 0.65   15.1875  1.35  ]
# current x [ 0.65   15.1875  1.35  ]
# pending candidatas...
# step 161, 0.08015624999999998, next x, [ 0.65   15.125   1.4125]
# current x [ 0.65   15.125   1.4125]
# pending candidatas...
# step 162, 0.04578124999999999, next x, [ 0.5875 15.125   1.35  ]
# current x [ 0.5875 15.125   1.35  ]
# pending candidatas...
# step 163, 0.04578124999999998, next x, [ 0.65   15.0625  1.35  ]
# current x [ 0.65   15.0625  1.35  ]
# pending candidatas...
# step 164, 0.048906249999999984, next x, [ 0.65   15.125   1.2875]
# current x [ 0.65   15.125   1.2875]
# no candidates...
# step 165, 0.08328124999999997, next x, [ 0.7125 15.125   1.35  ]
# current x [ 0.7125 15.125   1.35  ]
# pending candidatas...
# step 166, 0.08328124999999999, next x, [ 0.5875 15.25    1.35  ]
# current x [ 0.5875 15.25    1.35  ]
# pending candidatas...
# step 167, 0.09265624999999998, next x, [ 0.5875 15.125   1.475 ]
# current x [ 0.5875 15.125   1.475 ]
# pending candidatas...
# step 168, 0.02390625, next x, [ 0.4625 15.125   1.35  ]
# current x [ 0.4625 15.125   1.35  ]
# pending candidatas...
# step 169, 0.039531249999999976, next x, [ 0.5875 15.      1.35  ]
# current x [ 0.5875 15.      1.35  ]
# pending candidatas...
# step 170, 0.030156249999999978, next x, [ 0.5875 15.125   1.225 ]
# current x [ 0.5875 15.125   1.225 ]
# no candidates...
# step 171, 0.09890624999999996, next x, [ 0.65  15.125  1.35 ]
# current x [ 0.65  15.125  1.35 ]
# pending candidatas...
# step 172, 0.060624999999999984, next x, [ 0.5875 15.1875  1.35  ]
# current x [ 0.5875 15.1875  1.35  ]
# pending candidatas...
# step 173, 0.06531249999999998, next x, [ 0.5875 15.125   1.4125]
# current x [ 0.5875 15.125   1.4125]
# pending candidatas...
# step 174, 0.030937499999999986, next x, [ 0.525 15.125  1.35 ]
# current x [ 0.525 15.125  1.35 ]
# pending candidatas...
# step 175, 0.03874999999999998, next x, [ 0.5875 15.0625  1.35  ]
# current x [ 0.5875 15.0625  1.35  ]
# pending candidatas...
# step 176, 0.03406249999999998, next x, [ 0.5875 15.125   1.2875]
# current x [ 0.5875 15.125   1.2875]
# no candidates...
# step 177, 0.06843749999999996, next x, [ 0.7125 15.125   1.4125]
# current x [ 0.7125 15.125   1.4125]
# pending candidatas...
# step 178, 0.0684375, next x, [ 0.5875 15.25    1.4125]
# current x [ 0.5875 15.25    1.4125]
# pending candidatas...
# step 179, 0.07781249999999999, next x, [ 0.5875 15.125   1.5375]
# current x [ 0.5875 15.125   1.5375]
# pending candidatas...
# step 180, 0.02468750000000001, next x, [ 0.4625 15.125   1.4125]
# current x [ 0.4625 15.125   1.4125]
# pending candidatas...
# step 181, 0.02468749999999998, next x, [ 0.5875 15.      1.4125]
# current x [ 0.5875 15.      1.4125]
# pending candidatas...
# step 182, 0.01531249999999999, next x, [ 0.5875 15.125   1.2875]
# current x [ 0.5875 15.125   1.2875]
# no candidates...
# step 183, 0.06843749999999996, next x, [ 0.65   15.125   1.4125]
# current x [ 0.65   15.125   1.4125]
# pending candidatas...
# step 184, 0.04578124999999999, next x, [ 0.5875 15.1875  1.4125]
# current x [ 0.5875 15.1875  1.4125]
# pending candidatas...
# step 185, 0.050468749999999986, next x, [ 0.5875 15.125   1.475 ]
# current x [ 0.5875 15.125   1.475 ]
# pending candidatas...
# step 186, 0.02390625, next x, [ 0.525  15.125   1.4125]
# current x [ 0.525  15.125   1.4125]
# pending candidatas...
# step 187, 0.023906249999999983, next x, [ 0.5875 15.0625  1.4125]
# current x [ 0.5875 15.0625  1.4125]
# pending candidatas...
# step 188, 0.019218749999999986, next x, [ 0.5875 15.125   1.35  ]
# current x [ 0.5875 15.125   1.35  ]
# no candidates...
# step 189, 0.04578124999999998, next x, [ 0.7125 15.0625  1.4125]
# current x [ 0.7125 15.0625  1.4125]
# pending candidatas...
# step 190, 0.05671874999999999, next x, [ 0.5875 15.1875  1.4125]
# current x [ 0.5875 15.1875  1.4125]
# pending candidatas...
# step 191, 0.050468749999999986, next x, [ 0.5875 15.0625  1.5375]
# current x [ 0.5875 15.0625  1.5375]
# pending candidatas...
# step 192, 0.01296875000000001, next x, [ 0.4625 15.0625  1.4125]
# current x [ 0.4625 15.0625  1.4125]
# pending candidatas...
# step 193, 0.012968749999999984, next x, [ 0.5875 14.9375  1.4125]
# current x [ 0.5875 14.9375  1.4125]
# pending candidatas...
# step 194, 0.019218749999999986, next x, [ 0.5875 15.0625  1.2875]
# current x [ 0.5875 15.0625  1.2875]
# no candidates...
# step 195, 0.056718749999999964, next x, [ 0.65   15.0625  1.4125]
# current x [ 0.65   15.0625  1.4125]
# pending candidatas...
# step 196, 0.03406249999999999, next x, [ 0.5875 15.125   1.4125]
# current x [ 0.5875 15.125   1.4125]
# pending candidatas...
# step 197, 0.030937499999999986, next x, [ 0.5875 15.0625  1.475 ]
# current x [ 0.5875 15.0625  1.475 ]
# pending candidatas...
# step 198, 0.012187499999999999, next x, [ 0.525  15.0625  1.4125]
# current x [ 0.525  15.0625  1.4125]
# pending candidatas...
# step 199, 0.012187499999999987, next x, [ 0.5875 15.      1.4125]
